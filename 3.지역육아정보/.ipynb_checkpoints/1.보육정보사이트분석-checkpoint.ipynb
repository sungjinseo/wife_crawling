# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\python311\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\python311\lib\site-packages (from geopy) (2.0)

# %%
import requests
import json
import time
import copy
import re
import math
from bs4 import BeautifulSoup as bs

# %%
def web_request(method_name, url, dict_data, is_urlencoded=True):
    """Web GET or POST request를 호출 후 그 결과를 dict형으로 반환 """
    method_name = method_name.upper()  # 메소드이름을 대문자로 바꾼다
    if method_name not in ('GET', 'POST'):
        raise Exception('method_name is GET or POST plz...')

    if method_name == 'GET':  # GET방식인 경우
        response = requests.get(url=url, params=dict_data)
    elif method_name == 'POST':  # POST방식인 경우
        if is_urlencoded is True:
            response = requests.post(url=url, data=dict_data,
                                     headers={'Content-Type': 'application/x-www-form-urlencoded'})
        else:
            response = requests.post(url=url, data=json.dumps(dict_data), headers={'Content-Type': 'application/json'})

    dict_meta = {'status_code': response.status_code, 'ok': response.ok, 'encoding': response.encoding,
                 'Content-Type': response.headers['Content-Type']}
    if 'json' in str(response.headers['Content-Type']):  # JSON 형태인 경우
        return {**dict_meta, **response.json()}
    else:  # 문자열 형태인 경우
        return {**dict_meta, **{'text': response.text}}

# %%
LIST_PAGE = 'https://icare.seoul.go.kr/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do'
DETAIL_PAGE = 'https://icare.seoul.go.kr/icare/user/fcltyInfoManage/BD_selectFcltyInfoManage.do'
REQ_POST = 'POST'

# %%
탭목록 = []
list_res = web_request(REQ_POST, LIST_PAGE, {'q_hiddenVal':'1','q_searchAt':'Y'})
list_html = bs(list_res['text'], "html.parser")
for item in list_html.select('div.mt_10 li'):
    if item.text == '전체': continue
    cd_val = item.select_one('a')['onclick']
    cd_val = cd_val[cd_val.index('(')+2:cd_val.index(')')-1]
    temp_dict = {'label':item.text,'q_hiddenVal':'1','q_searchAt':'Y','q_currPage':'1'
                 ,'q_fcltyClCode':'1005','q_tabVal':cd_val,'q_svcClCode':cd_val}
    
    if cd_val == '1008':
        temp_dict['q_moreSvc'] = '2002,2003'
    else:
        temp_dict['q_moreSvc'] = cd_val
    
    탭목록.append(temp_dict)

# %%
#8개의 항목이 있는데 주소는 다 있어도 상세화면이 다르다 화면별로 스크래핑할거 고민해보자
#초등돌봄, 영유아보육시설, 교육, 지역보육정보, 방과후아카데미 주소는 있으나 좌표정보가 없음, 조회할 방법 찾아봐야함.
for item in 탭목록:
    print(item)
# Out:
# {'label': '우리동네 키움센터', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1001', 'q_svcClCode': '1001', 'q_moreSvc': '1001'}
# {'label': '지역 아동센터', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1003', 'q_svcClCode': '1003', 'q_moreSvc': '1003'}
# {'label': '초등돌봄교실', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1005', 'q_svcClCode': '1005', 'q_moreSvc': '1005'}
# {'label': '공동육아방', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1002', 'q_svcClCode': '1002', 'q_moreSvc': '1002'}
# {'label': '공동육아 나눔터', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1004', 'q_svcClCode': '1004', 'q_moreSvc': '1004'}
# {'label': '방과후 아카데미', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1010', 'q_svcClCode': '1010', 'q_moreSvc': '1010'}
# {'label': '영.유아 보육시설', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1006', 'q_svcClCode': '1006', 'q_moreSvc': '1006'}
# {'label': '교육', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1008', 'q_svcClCode': '1008', 'q_moreSvc': '2002,2003'}
# {'label': '지역보육정보', 'q_hiddenVal': '1', 'q_searchAt': 'Y', 'q_currPage': '1', 'q_fcltyClCode': '1005', 'q_tabVal': '1007', 'q_svcClCode': '1007', 'q_moreSvc': '1007'}

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')
# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
37.5971213, 127.05198672345011

# %%
geocoding('서울특별시 양천구 신월로24길 19')
# 지오코딩으로 찾을경우 신월사거리를 찾아주고 사이트에서 있는 좌표는 신월종합사회복지관 이다.
# Out:
# [37.5971213, 127.05198672345011]

# %%
setPoint('37.52005','126.84735','양천구 5호점 우리동네키움센터 (융합형)','pin_1.png');

# %%
# 송파구 아이돌봄센터 내역을 가져온뒤에 해당 페이지에 있는 코드값을 파싱하여 코드표를 준비한다
list_res = web_request(REQ_POST, LIST_PAGE, 탭목록[0])
list_html = bs(list_res['text'], "html.parser")

# %%
list_html
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/icare/resources/idolbom/img/main/favicon.ico" rel="SHORTCUT ICON"/>
# <title>
#
#
# 		맞춤형정보 : HOME &gt; 홍보·자료 &gt; 돌봄 정보찾기 &gt; 맞춤형정보
#
# </title>
# <!-- customize -->
# <link href="/icare/resources/openworks4/css/openworks4-custom.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var CTX_PATH="";</script>
# <!-- jquery core -->
# <!-- <script type="text/javascript" src="/icare/resources/libs/jquery/jquery-1.11.2.min.js"></script> -->
# <script src="/icare/resources/idolbom/js/lib/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.js" type="text/javascript"></script>
# <!-- 설정 동기화 -->
# <script src="/icare/component/js/ND_globalConfig.do" type="text/javascript"></script>
# <script src="/icare/component/js/ND_massageConfig.do" type="text/javascript"></script>
# <!-- Openworks 공통 메소드 -->
# <script src="/icare/resources/openworks4/js/openworks.global.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.message.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.initialize.js" type="text/javascript"></script>
# <link href="/icare/resources/idolbom/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/layout_media.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/main_new.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/sub_content.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/sub_content_media.css" rel="stylesheet" type="text/css"/>
# <script src="/icare/resources/idolbom/js/lib/bxslider.min.js"></script>
# <script src="/icare/resources/idolbom/js/layout.js"></script>
# <script src="/icare/resources/idolbom/js/sub.js"></script>
# <link href="/icare/resources/idolbom/css/add_200221.css" rel="stylesheet" type="text/css"/><!-- 20200221 팝업 css -->
# <link href="/icare/resources/idolbom/css/add_sns.css" rel="stylesheet" type="text/css"/><!-- 20200422 sns 추가 css -->
# <script src="https://www.seoul.go.kr/seoulgnb/gnb.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.form.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.ui.js" type="text/javascript"></script>
# <link href="/icare/resources/libs/fancybox-2.1.5/css/jquery.fancybox.css" rel="stylesheet" type="text/css">
# <script src="/icare/resources/libs/fancybox-2.1.5/js/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.modal.js" type="text/javascript"></script>
# <script src="/icare/resources/libs/form-3.51.0/jquery.form.js" type="text/javascript"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154136673-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-154136673-1');
# </script>
# <!-- 모니터링 -->
# <script type="text/javascript">
# 	var _bwa = [];
# 	_bwa.push(['setCollectorUrl', 'https://www.zesinc.co.kr/api/collector/icare']);
# 	_bwa.push(['setCustomerId', 'icare']);
# 	var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
# 	g.type='text/javascript';
# 	g.src="/icare/resources/openworks4/js/blueworksWebAgent-2_1-min.js";
# 	g.async=g.defer=true;
# 	s.parentNode.insertBefore(g, s);
# </script>
# <script>
# 	/* 초기화 */
# 	$(document).ready(function() {
# 		window.onload = function() {
# 			Yjs.Gnb.init("G248", "seoul-common-gnb");
# 		};
# 	});
#
# 	/* 개발 로그인 */
# 	/* var devLoginPop = function() {
# 		$().opmodal({
# 			href : "/icare/user/mypage/PD_devLoginForm.do",
# 			width : 500
# 		});
# 	} */
# </script>
# <script type="text/javascript">
#     var CTX_PATH="";
# </script>
# <script type="text/javascript">
# 		//<![CDATA[
#
# 		/* 공통 초기화 기능 */
# 		$(document).ready(function() {
#
# 			$("#q_searchVal").keypress(function (e) {
# 				if (e.which == 13){
# 					searchBtn();
# 				}
# 			});
#
# 			// 이용연령 전체 선택
# 			$("#age_all").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("input:checkbox[id^=age_]").prop("checked", true);
# 				} else {
# 					$("input:checkbox[id^=age_]").prop("checked", false);
# 				}
# 			});
#
# 			// 모바일 버전 일 때 이용연령 선택시 서비스 분류 노출
# 			var windowWidth = $( window ).width();
# 			if(windowWidth < 767) {
# 				$("input:checkbox[id^=age_]").click(function(){
# 					var checked = $(this).prop("checked");
# 					if(checked){
# 						$(".service_select02 > h3").parent().addClass('open');
# 					}else{
# 						var num = $("input:checkbox[id^=age_]:checked").length;
# 						if(num == 0){
# 							$(".service_select02 > h3").parent().removeClass('open');
# 						}
# 					}
# 				});
# 			};
#
# 			// 이용연령 선택
# 			$("input:checkbox[id^=age_]").click(function(){
# 				var checked = $(this).prop("checked");
# 				var num = $("input:checkbox[id^=age_]").not("#age_all").length;
# 				var num2 = $("input:checkbox[id^=age_]:checked").not("#age_all").length;
# 				if(num == num2){
# 					$("input:checkbox[id^=age_]").prop("checked", true);
# 				}
# 			});
#
# 			// 기타시설
# 			$("input:checkbox[name=q_fcltyCl]").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("#fcltyCl").val(1007);
# 					$("#fcltyCl").prop("disabled", false);
# 				} else {
# 					if($("input:checkbox[name=q_fcltyCl]:checked").length == 0){
# 						$("#fcltyCl").prop("disabled", true);
# 					}else{
# 						$("#fcltyCl").val();
# 					}
# 				}
# 			});
#
# 			//기타시설이 하나라도 체크되어 있을 때
# 			if($("input:checkbox[name=q_fcltyCl]:checked").length > 0){
# 				$("#fcltyCl").val(1007);
# 				$("#fcltyCl").prop("disabled", false);
# 			} else {
# 				$("#fcltyCl").prop("disabled", true);
# 			}
#
# 			//지역 전체 선택
# 			$("#area_all").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("input:checkbox[id^=area_]").prop("checked", true);
# 				} else {
# 					$("input:checkbox[id^=area_]").prop("checked", false);
# 				}
# 			});
#
# 			//지역 일부 선택
# 			$("input:checkbox[id^=area_]").click(function(){
# 				var num = $("input:checkbox[id^=area_]").not("#area_all").length;
# 				var num2 = $("input:checkbox[id^=area_]:checked").not("#area_all").length;
# 				if(num == num2){
# 					$("input:checkbox[id=area_all]").prop("checked", true);
# 				}else{
# 					$("input:checkbox[id=area_all]").prop("checked", false);
# 				}
# 			});
# 		});
#
# 		// 검색
# 		function searchBtn(){
# 			var num  = $("input:checkbox[id^=fac_0]:checked").length;
# 			var num2 = $("input:checkbox[id^=fac_1]:checked").length;
# 			var num3 = $("input:checkbox[id^=fac_2]:checked").length;
#
# 			// 구분값 하나 이상 선택
# 			if (num + num2 + num3 == 0) {
# 				alert("검색조건(시설 또는 교육)을 선택하세요");
# 				return false;
# 			} else {
# 				$("#q_currPage").val(1);
# 				$("#q_searchAt").val("Y");
# 				$("#q_tabVal").val("");
# 				$("#q_moreSvc").val("");
# 				$("#searchForm").submit();
# 			}
# 		};
#
# 		// 초기화
# 		function searchReset(){
# 			$("#searchForm").find("input").prop("disabled", true);
# 			$("#searchForm").submit();
# 		};
#
# 		// 페이지이동
# 		function jsMovePage(page){
# 			$("#q_currPage").val(page);
# 			$("#searchForm").submit();
# 		};
#
# 		// 탭이동
# 		var fnTabMove = function(tabVal) {
# 			var checked = "";
# 			if (tabVal == '1008') {        // 교육
# 				$("input:checkbox[id^=fac_2]:checked").each(function(i) {
# 					if (i != 0) {
# 						checked += ',';
# 					}
# 					checked += $(this).val();
# 				});
# 				$("#q_moreSvc").val(checked);
# 			} else if (tabVal == '1007') { // 지역보육정보
# 				$("input:checkbox[id^=fac_1]:checked").each(function(i) {
# 					if ($(this).val() != '2001') {
# 						checked = tabVal;
# 					} else {
# 						if (i != 0) {
# 							checked += ',';
# 						}
# 						checked += $(this).val();
# 					}
# 				});
# 				$("#q_moreSvc").val(checked);
# 			} else {
# 				$("#q_moreSvc").val(tabVal);
# 			}
# 			$("#q_tabVal").val(tabVal);
#
# 			$("#q_currPage").val(1);
# 			$("#q_searchAt").val("Y");
# 			$("#searchForm").submit();
# 		}
#
# 		// 더보기 버튼
# 		var moreBtn = function(svcClCode, fcltyClCode, trgetClCode) {
# 			if (svcClCode == "1008" || svcClCode == "1009") {
# 				$("#q_moreSvc").val("1001");
# 				$("#q_tabVal").val("1001");
# 			} else if (svcClCode == "1007") {
# 				$("#q_fcltyClCode").val(fcltyClCode);
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val(svcClCode);
# 			} else if (svcClCode == "2001") {
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val("1007");
# 			} else if (svcClCode == "2003") {
# 				if (trgetClCode == '1001') {
# 					$("#q_moreSvc").val("2002");
# 				} else {
# 					$("#q_moreSvc").val(svcClCode);
# 				}
# 				$("#q_tabVal").val("1008");
# 			} else {
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val(svcClCode);
# 			}
# 			$("#q_currPage").val(1);
# 			$("#q_searchAt").val("Y");
# 			$("#searchForm").submit();
# 		}
#
# 		// 상세보기
# 		var fnView = function(svcClCode, fcltyId, fcltyNm, siteUrl) {
# 			if (svcClCode == "1005" || svcClCode == "2003") {
# 				window.open(siteUrl, "_blank");
# 			} else if (svcClCode == "1007" || svcClCode == "2003") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "2001") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#q_gubun").val("1001");
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "2002") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#q_gubun").val("1002");
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "1006") {
# 				if (fcltyNm.indexOf("휴일보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("시간보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/night_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("365열린어린이집") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("거점형시간연장보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/dailyOpenPreschoolMiddle.do", "_blank");
# 				} else {
# 					window.open("https://iseoul.seoul.go.kr/portal/info/preSchoolList.do", "_blank");
# 				}
# 			} else if (svcClCode == "1008") {
# 				location.href = siteUrl;
# 			} else {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_fcltyId").val(fcltyId);
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			}
# 		}
#
# 		//]]>
# 	</script>
# <script type="text/javascript">
#     var anlzSessionId = "F77A4B626AAB03379092D9F1EB108729.tomcat2";
#     var anlzClientIp = "211.234.198.84";
#     var anlzMenuCode = "dolbomMENU4_1_1";
# </script>
# <script src="/icare/resources/openworks4/js/analyze/tracker.js" type="text/javascript"></script>
# </link></head>
# <body>
# <div id="skipNav">
# <p><a href="#container">본문바로가기</a></p>
# <p><a href="#gnb">주메뉴바로가기</a></p>
# </div>
# <div id="mask"></div>
# <div id="seoul-common-gnb"></div>
# <div class="header">
# <div class="header_con">
# <div id="gnb">
# <div class="header_inner">
# <h1 class="logo">
# <a href="javascript:goMain();" title="메인으로"><img alt="서울케어 우리동네키움포털" src="/icare/resources/idolbom/img/common/logo_new.png"/></a>
# </h1>
# <div class="m_gnbBtn">
# <button class="m_gnbOpen" type="button"><img alt="메뉴열기" src="/icare/resources/idolbom/img/common/m_gnb.png"/></button>
# <button class="m_gnbClose" type="button"><img alt="메뉴닫기" src="/icare/resources/idolbom/img/common/m_gnb_close.png"/></button>
# </div>
# <div class="gnb_wrap">
# <div class="m_login">
# <ul class="btn">
# <li class="login_btn"><a href="/icare/login/BD_loginForm.do">로그인</a></li>
# <li class="join_btn"><a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">회원가입</a></li>
# </ul>
# <div class="m_sns">
# <a class="blog" href="https://blog.naver.com/seoulkium" title="우리동네키움센터 네이버블로그 새창열림"><span>우리동네키움센터<br/>네이버블로그</span></a>
# <a class="youtube" href="https://www.youtube.com/channel/UChV3e-MPtIwdEU6Md14Bo3A" title="우리동네키움튜브 새창열림"><span>우리동네키움튜브</span></a>
# </div>
# </div>
# <ul>
# <li class="m_gnb_on">
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="초등돌봄 바로가기">초등돌봄</a>
# <a class="mn" href="#none;">초등돌봄</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="일반/융합형 우리동네키움센터 바로가기">일반/융합형 우리동네키움센터</a>
# <a class="mn" href="#none;">일반/융합형 우리동네키움센터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="서비스소개 바로가기">서비스소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=2" title="이용안내 바로가기">이용안내</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=3" title="센터연락처(서울소재) 바로가기">센터연락처(서울소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=4" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_1.jsp" title="거점형 키움센터 바로가기">거점형 키움센터</a>
# <a class="mn" href="#none;">거점형 키움센터</a>
# <ul>
# <li>
# <a href="#none;" title="열기">거점1호 (노원·도봉권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점2호 (동작권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점3호 (종로·서대문권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점5호 (성북권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=1" title="지역아동센터 바로가기">지역아동센터</a>
# <a class="mn" href="#none;">지역아동센터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=2" title="이용안내 바로가기">이용안내</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=3" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=4" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_4/dolbomMENU1_4_1.jsp" title="청소년방과후아카데미 바로가기">청소년방과후아카데미</a>
# <a class="mn" href="#none;">청소년방과후아카데미</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_4/dolbomMENU1_4_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCenterContactList.do?q_gubunCd=1010" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_5/dolbomMENU1_5_1.jsp" title="초등돌봄교실 바로가기">초등돌봄교실</a>
# <a class="mn" href="#none;">초등돌봄교실</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_5/dolbomMENU1_5_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCenterContactList.do?q_gubunCd=1005" title="초등돌봄 연락처(서울 소재) 바로가기">초등돌봄 연락처(서울 소재)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="영유아돌봄 바로가기">영유아돌봄</a>
# <a class="mn" href="#none;">영유아돌봄</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="공동육아방 바로가기">공동육아방</a>
# <a class="mn" href="#none;">공동육아방</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=2" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=3" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=1" title="공동육아나눔터 바로가기">공동육아나눔터</a>
# <a class="mn" href="#none;">공동육아나눔터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=2" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=3" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_1.jsp" title="아이돌봄 서비스 바로가기">아이돌봄 서비스</a>
# <a class="mn" href="#none;">아이돌봄 서비스</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_2.jsp" title="서비스 제공기관 바로가기">서비스 제공기관</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=1" title="우리동네 보육반장 바로가기">우리동네 보육반장</a>
# <a class="mn" href="#none;">우리동네 보육반장</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=2" title="우리동네 꼼꼼 육아정보 바로가기">우리동네 꼼꼼 육아정보</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=3" title="우리동네보육반장 연락처 바로가기">우리동네보육반장 연락처</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1005" title="활동소식 바로가기">활동소식</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 바로가기">서울형 키즈카페</a>
# <a class="mn" href="#none;">서울형 키즈카페</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 소개 바로가기">서울형 키즈카페 소개</a>
# <a class="mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 소개 바로가기">서울형 키즈카페 소개</a>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/kidsCafe/BD_selectKidsCafeList.do" title="서울형 키즈카페 안내 바로가기">서울형 키즈카페 안내</a>
# <a class="mn" href="/icare/user/kidsCafe/BD_selectKidsCafeList.do" title="서울형 키즈카페 안내 바로가기">서울형 키즈카페 안내</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약신청 바로가기">예약신청</a>
# <a class="mn" href="#none;">예약신청</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="돌봄 서비스 바로가기">돌봄 서비스</a>
# <a class="mn" href="#none;">돌봄 서비스</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약안내 바로가기">예약안내</a>
# </li>
# <li>
# <a href="#none;" title="열기">거점형키움센터 예약</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_2/dolbomMENU3_1_2_1.jsp" title="일시·긴급돌봄 서비스 바로가기">일시·긴급돌봄 서비스</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_2/dolbomMENU3_1_2_2.jsp" title="아픈아이 돌봄 서비스 바로가기">아픈아이 돌봄 서비스</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/icare/user/careResve/BD_selectChilCareResveList.do" title="우리동네키움센터 예약 바로가기">우리동네키움센터 예약</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_1/dolbomMENU3_2_1_1.jsp" title="체험 서비스 바로가기">체험 서비스</a>
# <a class="mn" href="#none;">체험 서비스</a>
# <ul>
# <li>
# <a href="#none;" title="열기">창의체험 활동</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_1/dolbomMENU3_2_1_1.jsp" title="문화예술창작활동 소개 바로가기">문화예술창작활동 소개</a>
# </li>
# <li>
# <a href="/icare/user/chilProgrm/orgideaExprnCtzn/BD_selectOrgideaExprnCtznList.do?q_progrmCl=1000&amp;q_placeCode=100" title="문화예술창작활동 신청 바로가기">문화예술창작활동 신청</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">특화프로그램 활동</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_2/dolbomMENU3_2_2_1.jsp" title="특화프로그램 소개 바로가기">특화프로그램 소개</a>
# </li>
# <li>
# <a href="/icare/user/chilProgrm/orgideaExprnCtzn/BD_selectOrgideaExprnCtznList.do?q_progrmCl=2000&amp;q_placeCode=100" title="특화프로그램 신청 바로가기">특화프로그램 신청</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="홍보·자료 바로가기">홍보·자료</a>
# <a class="mn" href="#none;">홍보·자료</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 정보찾기 바로가기">돌봄 정보찾기</a>
# <a class="mn" href="#none;">돌봄 정보찾기</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 서비스 문의처 바로가기">돌봄 서비스 문의처</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형정보 바로가기">맞춤형정보</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU4/dolbomMENU4_1/dolbomMENU4_1_2.jsp" title="아이돌봄지도서비스 바로가기">아이돌봄지도서비스</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="알림방 바로가기">알림방</a>
# <a class="mn" href="#none;">알림방</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="공지사항 바로가기">공지사항</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1003" title="우리동네키움센터소식 바로가기">우리동네키움센터소식</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1021" title="채용소식 바로가기">채용소식</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1025" title="고시/공고 바로가기">고시/공고</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="홍보방 바로가기">홍보방</a>
# <a class="mn" href="#none;">홍보방</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="동영상 바로가기">동영상</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1004" title="갤러리 바로가기">갤러리</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1030" title="프로젝트기반배움(PBL) 운영사례 바로가기">프로젝트기반배움(PBL) 운영사례</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="자료실 바로가기">자료실</a>
# <a class="mn" href="#none;">자료실</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="키움센터 뉴스레터 바로가기">키움센터 뉴스레터</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1018" title="자료실 바로가기">자료실</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a>
# <a class="mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <ul class="util_menu">
# <li class="login">
# <a href="/icare/login/BD_loginForm.do">
# 									로그인
# 								</a>
# </li>
# <li class="join">
# <a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">
# 									회원가입
# 								</a>
# </li>
# </ul>
# </div><!--gnb_wrap END-->
# <div class="m_gnb_bg"></div>
# </div><!--gnb END-->
# </div><!--header_wrap END-->
# </div><!--//header END-->
# <div class="location">
# <div class="location_wrap">
# <ul>
# <li class="home">
# <a href="/icare/index.do"><img alt="메인으로" src="/icare/resources/idolbom/img/common/sta_home.png"/></a>
# </li>
# <li class="m_location"><!--모바일쪽 로케이션-->
# <p>맞춤형정보</p>
# </li>
# <li class="location_bar main"><!--pc쪽 로케이션-->
# <a class="mainMenu" href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do;jsessionid=F77A4B626AAB03379092D9F1EB108729.tomcat2" title="주메뉴 선택, 축소됨">홍보·자료</a>
# <ul>
# <li><a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="초등돌봄 바로가기">초등돌봄</a></li>
# <li><a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="영유아돌봄 바로가기">영유아돌봄</a></li>
# <li><a href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 바로가기">서울형 키즈카페</a></li>
# <li><a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약신청 바로가기">예약신청</a></li>
# <li class="lb_on"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="홍보·자료 바로가기">홍보·자료</a></li>
# </ul>
# </li>
# <li class="location_bar sub"><!--pc쪽 로케이션 2depth-->
# <a class="subMenu" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="하위메뉴 선택, 축소됨">돌봄 정보찾기</a>
# <ul>
# <li class="lb_on"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 정보찾기 바로가기">돌봄 정보찾기</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="알림방 바로가기">알림방</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="홍보방 바로가기">홍보방</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="자료실 바로가기">자료실</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a></li>
# </ul>
# </li>
# <li class="location_bar sub"><!--pc쪽 로케이션 3depth-->
# <a class="subMenu" href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="하위메뉴 선택, 축소됨">맞춤형정보</a>
# <ul>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 서비스 문의처 바로가기">돌봄 서비스 문의처</a></li>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li class="lb_on"><a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형정보 바로가기">맞춤형정보</a></li>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li><a href="/icare/dolbomMENU4/dolbomMENU4_1/dolbomMENU4_1_2.jsp" title="아이돌봄지도서비스 바로가기">아이돌봄지도서비스</a></li>
# </ul>
# </li>
# </ul>
# </div><!--location_wrap END-->
# </div><!--location END-->
# <div class="sub_container" id="container">
# <div class="sub_content">
# <h2 class="sub_title01 mb_55">맞춤형 정보 서비스</h2>
# <form action="BD_selectFcltyInfoManageList.do" class="form-horizontal" id="searchForm" method="post" name="searchForm">
# <input id="q_clturEventEtcSn" name="q_clturEventEtcSn" type="hidden" value=""/>
# <input id="q_fcltyId" name="q_fcltyId" type="hidden" value=""/>
# <input id="q_fclty" name="q_fclty" type="hidden" value=""/>
# <input id="q_gubun" name="q_gubun" type="hidden" value=""/>
# <input id="q_eduProgramVal" name="q_eduProgramVal" type="hidden" value=""/>
# <input id="q_hiddenVal" name="q_hiddenVal" type="hidden" value="1"/>
# <input id="q_fcltyClCode" name="q_fcltyClCode" type="hidden" value="1005"/>
# <input id="q_searchAt" name="q_searchAt" type="hidden" value="Y"/>
# <input id="q_moreSvc" name="q_moreSvc" type="hidden" value="1001"/>
# <input id="q_tabVal" name="q_tabVal" type="hidden" value="1001"/>
# <div class="table_ty01 m_table_ty01 table_ty_01_pd">
# <table class="center">
# <caption>맞춤형 정보 서비스 검색폼(구분(돌봄시설,지역보육정보,교육),이용연령,자치구,검색어)</caption>
# <colgroup>
# <col style="width: 3%"/>
# <col style="width: 12%"/>
# <col style="width: auto"/>
# </colgroup>
# <tbody>
# <tr>
# <th rowspan="3" scope="row">구분</th>
# <th scope="row">돌봄시설</th>
# <td>
# <ul class="fixe_chk">
# <li class="fclty"><input checked="checked" id="fac_01" name="q_svcClCode" type="checkbox" value="1001"/><label for="fac_01">우리동네 키움센터</label></li>
# <li class="fclty"><input id="fac_02" name="q_svcClCode" type="checkbox" value="1003"/><label for="fac_02">지역 아동센터</label></li>
# <li class="fclty"><input id="fac_03" name="q_svcClCode" type="checkbox" value="1005"/><label for="fac_03">초등 돌봄교실</label></li>
# <li class="fclty"><input id="fac_04" name="q_svcClCode" type="checkbox" value="1002"/><label for="fac_04">공동육아방</label></li>
# <li class="fclty"><input id="fac_05" name="q_svcClCode" type="checkbox" value="1004"/><label for="fac_05">공동육아 나눔터</label></li>
# <li class="fclty"><input id="fac_07" name="q_svcClCode" type="checkbox" value="1010"/><label for="fac_07">청소년방과후아카데미</label></li>
# <li class="fclty"><input id="fac_06" name="q_svcClCode" type="checkbox" value="1006"/><label for="fac_06">영·유아 보육시설</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th scope="row">지역보육정보</th>
# <td>
# <input id="fcltyCl" name="q_svcClCode" type="hidden" value="">
# <ul class="area_chk">
# <li><input id="fac_10" name="q_fcltyCl" type="checkbox" value="1001"/><label for="fac_10">야외 시설</label></li>
# <li><input id="fac_11" name="q_fcltyCl" type="checkbox" value="1003"/><label for="fac_11">도서관</label></li>
# <li><input id="fac_12" name="q_fcltyCl" type="checkbox" value="1004"/><label for="fac_12">의료 시설</label></li>
# <li><input id="fac_13" name="q_fcltyCl" type="checkbox" value="1002"/><label for="fac_13">체험 시설</label></li>
# <li><input id="fac_14" name="q_fcltyCl" type="checkbox" value="1005"/><label for="fac_14">관공서</label></li>
# </ul>
# </input></td>
# </tr>
# <tr>
# <th scope="row">교육</th>
# <td>
# <ul class="fixe_chk">
# <li><input id="fac_21" name="q_clturEvent" type="checkbox" value="2002"/><label for="fac_21">초등생 교육 프로그램</label></li>
# <li><input id="fac_22" name="q_clturEvent" type="checkbox" value="2003"/><label for="fac_22">영·유아 교육 프로그램</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="2" scope="row">이용연령</th>
# <td>
# <ul class="area_chk">
# <li><input id="age_all" name="q_ageSeCode" type="checkbox" value="1000"/><label for="age_all">전체</label></li>
# <li><input id="age_01" name="q_ageSeCode" type="checkbox" value="1001"/><label for="age_01">영·유아</label></li>
# <li><input id="age_02" name="q_ageSeCode" type="checkbox" value="1002"/><label for="age_02">유치원생</label></li>
# <li><input id="age_03" name="q_ageSeCode" type="checkbox" value="1003"/><label for="age_03">초등학생</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="2" scope="row">자치구</th>
# <td>
# <ul class="area_chk">
# <li class="area_li"><input id="area_all" name="q_atdrcCode" type="checkbox" value="1000"/><label for="area_all">전체</label></li>
# <li class="area_li"><input id="area_1" name="q_atdrcCode" type="checkbox" value="11680"/><label for="area_1">강남구</label></li>
# <li class="area_li"><input id="area_2" name="q_atdrcCode" type="checkbox" value="11740"/><label for="area_2">강동구</label></li>
# <li class="area_li"><input id="area_3" name="q_atdrcCode" type="checkbox" value="11305"/><label for="area_3">강북구</label></li>
# <li class="area_li"><input id="area_4" name="q_atdrcCode" type="checkbox" value="11500"/><label for="area_4">강서구</label></li>
# <li class="area_li"><input id="area_5" name="q_atdrcCode" type="checkbox" value="11620"/><label for="area_5">관악구</label></li>
# <li class="area_li"><input id="area_6" name="q_atdrcCode" type="checkbox" value="11215"/><label for="area_6">광진구</label></li>
# <li class="area_li"><input id="area_7" name="q_atdrcCode" type="checkbox" value="11530"/><label for="area_7">구로구</label></li>
# <li class="area_li"><input id="area_8" name="q_atdrcCode" type="checkbox" value="11545"/><label for="area_8">금천구</label></li>
# <li class="area_li"><input id="area_9" name="q_atdrcCode" type="checkbox" value="11350"/><label for="area_9">노원구</label></li>
# <li class="area_li"><input id="area_10" name="q_atdrcCode" type="checkbox" value="11320"/><label for="area_10">도봉구</label></li>
# <li class="area_li"><input id="area_11" name="q_atdrcCode" type="checkbox" value="11230"/><label for="area_11">동대문구</label></li>
# <li class="area_li"><input id="area_12" name="q_atdrcCode" type="checkbox" value="11590"/><label for="area_12">동작구</label></li>
# <li class="area_li"><input id="area_13" name="q_atdrcCode" type="checkbox" value="11440"/><label for="area_13">마포구</label></li>
# <li class="area_li"><input id="area_14" name="q_atdrcCode" type="checkbox" value="11410"/><label for="area_14">서대문구</label></li>
# <li class="area_li"><input id="area_15" name="q_atdrcCode" type="checkbox" value="11650"/><label for="area_15">서초구</label></li>
# <li class="area_li"><input id="area_16" name="q_atdrcCode" type="checkbox" value="11200"/><label for="area_16">성동구</label></li>
# <li class="area_li"><input id="area_17" name="q_atdrcCode" type="checkbox" value="11290"/><label for="area_17">성북구</label></li>
# <li class="area_li"><input id="area_18" name="q_atdrcCode" type="checkbox" value="11710"/><label for="area_18">송파구</label></li>
# <li class="area_li"><input id="area_19" name="q_atdrcCode" type="checkbox" value="11470"/><label for="area_19">양천구</label></li>
# <li class="area_li"><input id="area_20" name="q_atdrcCode" type="checkbox" value="11560"/><label for="area_20">영등포구</label></li>
# <li class="area_li"><input id="area_21" name="q_atdrcCode" type="checkbox" value="11170"/><label for="area_21">용산구</label></li>
# <li class="area_li"><input id="area_22" name="q_atdrcCode" type="checkbox" value="11380"/><label for="area_22">은평구</label></li>
# <li class="area_li"><input id="area_23" name="q_atdrcCode" type="checkbox" value="11110"/><label for="area_23">종로구</label></li>
# <li class="area_li"><input id="area_24" name="q_atdrcCode" type="checkbox" value="11140"/><label for="area_24">중구</label></li>
# <li class="area_li"><input id="area_25" name="q_atdrcCode" type="checkbox" value="11260"/><label for="area_25">중랑구</label></li>
# </ul>
# </td>
# </tr>
# <tr class="table_ty_01_pd_02">
# <th colspan="2" scope="row">검색어</th>
# <td>
# <ul class="service_search_btn" style="margin-top:0px;">
# <li class="search_input"><input id="q_searchVal" name="q_searchVal" placeholder="검색하실 우리동네키움센터명을 입력해주세요." title="키움센터명 검색어 입력" type="text" value=""/></li>
# </ul>
# </td>
# </tr>
# <tr class="table_ty_01_pd_02">
# <td colspan="3">
# <ul class="service_search_btn" style="margin-top:0px; float: right;">
# <li class="search_btn"><a href="#" onclick="searchBtn(); return false;"><img alt="검색버튼" src="/icare/resources/idolbom/img/sub/search_icon.png"/>검색</a></li>
# <li class="reset_btn"><a href="#" onclick="searchReset(); return false;"><img alt="초기화버튼" src="/icare/resources/idolbom/img/sub/reset_icon.png"/>초기화</a></li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="mt_10">
# <ul class="tab tab_li_10-1 m_tab_9">
# <li><a href="#" onclick="fnTabMove(''); return false;">전체</a></li>
# <li class="tab_on"><a href="#" onclick="fnTabMove('1001'); return false;">우리동네 키움센터</a></li>
# <li><a href="#" onclick="fnTabMove('1003'); return false;">지역 아동센터</a></li>
# <li><a href="#" onclick="fnTabMove('1005'); return false;">초등돌봄교실</a></li>
# <li><a href="#" onclick="fnTabMove('1002'); return false;">공동육아방</a></li>
# <li><a href="#" onclick="fnTabMove('1004'); return false;">공동육아 나눔터</a></li>
# <li><a href="#" onclick="fnTabMove('1010'); return false;">방과후 아카데미</a></li>
# <li><a href="#" onclick="fnTabMove('1006'); return false;">영.유아 보육시설</a></li>
# <li><a href="#" onclick="fnTabMove('1008'); return false;">교육</a></li>
# <li><a href="#" onclick="fnTabMove('1007'); return false;">지역보육정보</a></li>
# </ul>
# </div>
# <div class="board_box_ty02 mt_40">
# <p class="board_info">
# <span class="sr-only">페이지당 목록갯수 선택</span>
#
#
#
#
# 						전체 236건 (1페이지 / 전체 16페이지)
#
#
#
#
#
#
#
# 	<input id="q_rowPerPage" name="q_rowPerPage" type="hidden" value="15">
# <input id="q_currPage" name="q_currPage" type="hidden" value="1">
# <input id="q_sortName" name="q_sortName" type="hidden" value="">
# <input id="q_sortOrder" name="q_sortOrder" type="hidden" value="">
# </input></input></input></input></p>
# <ul>
# <li>
# <a href="#" onclick='fnView("1009","YC230101","양천구 5호점 우리동네키움센터 (융합형)","");'>
# <span class="box_title">양천구 5호점 우리동네키움센터 (융합형)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 양천구 신월로24길 19</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													070-
# 													8133-
# 													2463
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">융합형키움센터</b>
# <b>양천구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","KC230101","금천구 4호점 우리동네키움센터(시흥1동)","");'>
# <span class="box_title">금천구 4호점 우리동네키움센터(시흥1동)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 금천구 시흥대로 164</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													809-
# 													1999
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>금천구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","MP230101","마포구9호점 우리동네키움센터(합정동)","");'>
# <span class="box_title">마포구9호점 우리동네키움센터(합정동)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 마포구 양화로1길 108</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													322-
# 													2311
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>마포구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","GS221201","강서6호점 화곡8동 우리동네키움센터","");'>
# <span class="box_title">강서6호점 화곡8동 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 강서구 강서로5길 50</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													2602-
# 													1067
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>강서구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1009","GB221101","강북6호점 우리동네키움센터(융합형)(삼각산동)","");'>
# <span class="box_title">강북6호점 우리동네키움센터(융합형)(삼각산동)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 강북구 삼양로19길 102</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													988-
# 													1318
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">융합형키움센터</b>
# <b>강북구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","DM221001","동대문구 6호점 우리동네키움센터","");'>
# <span class="box_title">동대문구 6호점 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 동대문구 약령시로5길 22</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													920-
# 													4541
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>동대문구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","GA220501","관악3호점 우리동네키움센터","");'>
# <span class="box_title">관악3호점 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 관악구 청림2길 37</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													877-
# 													3055
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>관악구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1009","GR221001","구로19호점 우리동네키움센터(항동융합형)","");'>
# <span class="box_title">구로19호점 우리동네키움센터(항동융합형)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 구로구 연동로 191-19</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													2619-
# 													7942
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">융합형키움센터</b>
# <b>구로구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","DJ221101","동작14호점 우리동네키움센터(상도3동)","");'>
# <span class="box_title">동작14호점 우리동네키움센터(상도3동)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 동작구 상도로15가길 14</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													6953-
# 													4665
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>동작구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","SP220901","송파18호점 우리동네키움센터(위례동2호점 송파키움센터)","");'>
# <span class="box_title">송파18호점 우리동네키움센터(위례동2호점 송파키움센터)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 송파구 위례북로4길 12</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													431-
# 													5515
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>송파구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","EP220902","은평12호점 우리동네키움센터","");'>
# <span class="box_title">은평12호점 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 은평구 통일로 627</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													353-
# 													6184
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>은평구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","EP220901","은평11호점 우리동네키움센터","");'>
# <span class="box_title">은평11호점 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 은평구 통일로73길 16</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													359-
# 													9878
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>은평구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1008","BP220801","제5호(성북권) 거점형 우리동네키움센터","https://icare.seoul.go.kr/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_3.jsp");'>
# <span class="box_title">제5호(성북권) 거점형 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 성북구 회기로3길 17</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													6956-
# 													7033
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">거점형키움센터</b>
# <b>성북구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1009","GB220401","강북3호점 우리동네키움센터(융합형)(삼양동)","");'>
# <span class="box_title">강북3호점 우리동네키움센터(융합형)(삼양동)</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 강북구 인수봉로6길 39</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													989-
# 													9285
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">융합형키움센터</b>
# <b>강북구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# <li>
# <a href="#" onclick='fnView("1001","EP220801","은평10호점 우리동네키움센터","");'>
# <span class="box_title">은평10호점 우리동네키움센터</span>
# <p class="box_info_p">
# <span class="box_txt">
# <em>주소</em><b>서울특별시 은평구 은평로 114</b>
# </span>
# <span class="box_txt">
# <em>연락처</em>
# 													02-
# 													2135-
# 													6014
#
#
# 										</span>
# <span class="box_txt">
# <em>이용료</em>
#
#
#
# 															월 /
#
#
#
# 																	50,000 원
#
#
#
#
#
# 															일 /
#
#
#
# 																	2,500 원
#
#
#
#
#
#
#
#
#
# 											</span>
# </p>
# <span class="box_label">
# <!-- 우리동네키움센터 -->
# <b class="label_cl_01">우리동네키움센터</b>
# <b>은평구</b>
# <b>초등학생</b>
# </span>
# </a>
# </li>
# </ul>
# </div><!--board_box_ty02 END-->
# </form>
# <div class="paging mt_40">
# <ul>
# <li class="paging_num paging_num_on">
# <a href="#" onclick="return false;" title="현재 1 페이지">1</a>
# </li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(2); return false;" title="2 페이지">2</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(3); return false;" title="3 페이지">3</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(4); return false;" title="4 페이지">4</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(5); return false;" title="5 페이지">5</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(6); return false;" title="6 페이지">6</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(7); return false;" title="7 페이지">7</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(8); return false;" title="8 페이지">8</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(9); return false;" title="9 페이지">9</a></li>
# <li class="paging_num"><a href="#" onclick="jsMovePage(10); return false;" title="10 페이지">10</a></li>
# <li class="next_btn"><a href="#" onclick="jsMovePage(11); return false;" title="다음페이지그룹 가기"><img alt="다음" src="/icare/resources/idolbom/img/sub/next_btn.png"/></a></li>
# <li><a href="#" onclick="jsMovePage(16); return false;" title="마지막페이지로 가기"><img alt="마지막으로" src="/icare/resources/idolbom/img/sub/last_btn.png"/></a></li>
# </ul>
# </div>
# <!-- go top -->
# <span class="go-top"><a class="top" href="#"><img alt="top으로 바로가기" src="/icare/resources/idolbom/img/main/btn_top.png"/></a></span>
# <!-- //go top -->
# </div><!--sub_content END-->
# </div><!--container END-->
# <!-- Footer -->
# <footer class="footer" id="footer">
# <div class="footer_wrap">
# <div class="inner">
# <div class="footer-link">
# <!-- <div class="sns sns-new">
# 						RSS연동 후 주석 제거
# 						<a href="#" class="rss">RSS</a>
# 						<a href="https://www.facebook.com/seoul.kr" class="fb" target="_blank" title="새창열림" onclick="se_click_logging('https://www.facebook.com/seoul.kr?tr_code=sns',location.href);">페이스북</a>
# 						<a href="http://twitter.com/seoulmania" class="tw" target="_blank" title="새창열림" onclick="se_click_logging('http://twitter.com/seoulmania?tr_code=sns',location.href);">트위터</a>
# 						<a href="http://www.instagram.com/seoul_official" class="ins" target="_blank" title="새창열림" onclick="se_click_logging('http://www.instagram.com/seoul_official?tr_code=sns',location.href);">인스타그램</a>
# 						<a href="http://story.kakao.com/ch/seoul" class="ks" target="_blank" title="새창열림" onclick="se_click_logging('http://story.kakao.com/ch/seoul?tr_code=sns',location.href);">카카오스토리</a>
# 						<a href="http://www.youtube.com/seoullive" class="yt" target="_blank" title="새창열림" onclick="se_click_logging('http://www.youtube.com/seoullive?tr_code=sns',location.href);">유튜브</a>
# 						<a href="http://blog.seoul.go.kr" class="bl" target="_blank" title="새창열림" onclick="se_click_logging('http://blog.seoul.go.kr?tr_code=sns',location.href);">블로그</a>
# 					</div> -->
# <div class="seoul_banner">
# <div class="mobile_banner">
# <!-- Dighty : [우리동네키움포털] 모바일(신규) (664*140) 태그 -->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_b = '';
#    var m3_u = (location.protocol=='https:'?'https://delivery.dighty.com/www/delivery/ajs.php':'http://delivery.dighty.com/www/delivery/ajs.php');
#    var m3_r = Math.floor(Math.random()*99999999999);
#    if(document.cookie.indexOf('ACEUACS=')>-1){
#    var m3_b = document.cookie.substr(document.cookie.indexOf('ACEUACS=')+8,19);}
#    if (!document.MAX_used) document.MAX_used = ',';
#    document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#    document.write ("?zoneid=1010");
#    document.write ('&amp;cb=' + m3_r);
#    if (m3_b!='')document.write('&amp;bd=' + m3_b);
#    if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#    document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#    document.write ("&amp;loc=" + escape(window.location));
#    if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#    if (document.context) document.write ("&context=" + escape(document.context));
#    if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#    document.write ("'><\/scr"+"ipt>");
# //]]>--></script>
# <noscript>
# <a href="https://delivery.dighty.com/www/delivery/ck.php?n=1e48c442&amp;cb=INSERT_RANDOM_NUMBER_HERE" rel="noopener noreferrer" target="_blank">
# <img alt="" src="https://delivery.dighty.com/www/delivery/avw.php?zoneid=1010&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=1e48c442"/></a>
# </noscript>
# </div>
# <div class="pc_banner">
# <!-- NHN ACE : [우리동네키움포털] 메인하단 (1200*70) 태그 -->
# <script type="text/javascript">
# //<![CDATA[
#    var m3_b = '';
#    var m3_u = (location.protocol=='https:'?'https://delivery.dighty.com/www/delivery/ajs.php':'http://delivery.dighty.com/www/delivery/ajs.php');
#    var m3_r = Math.floor(Math.random()*99999999999);
#    if(document.cookie.indexOf('ACEUACS=')>-1){
#    var m3_b = document.cookie.substr(document.cookie.indexOf('ACEUACS=')+8,19);}
#    if (!document.MAX_used) document.MAX_used = ',';
#    document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#    document.write ("?zoneid=807");
#    document.write ('&amp;cb=' + m3_r);
#    if (m3_b!='')document.write('&amp;bd=' + m3_b);
#    if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#    document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#    document.write ("&amp;loc=" + escape(window.location));
#    if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#    if (document.context) document.write ("&context=" + escape(document.context));
#    if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#    document.write ("'><\/scr"+"ipt>");
# //]]>
# </script>
# <noscript>
# <a href="https://delivery.dighty.com/www/delivery/ck.php?n=6e7b33fd&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank" title="새창열림">
# <img alt="" src="https://delivery.dighty.com/www/delivery/avw.php?zoneid=807&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=6e7b33fd"/></a>
# </noscript>
# </div>
# </div>
# </div>
# </div>
# </div><!--footer_wrap END-->
# <div class="footer_wrap02">
# <div class="row">
# <div class="inner">
# <div class="seoul_logo"> <!-- 211130 seoul_logo class 추가 -->
# <a href="http://www.seoul.go.kr" rel="noopener" target="_blank" title="새창으로 열림">
# <img alt="I SEOUL U 로고" src="/icare/resources/idolbom/img/footer/img_brand1.png" title="I SEOUL U 로고">
# </img></a>
# </div>
# <div class="footer_info">
# <ul class="footer_link02"> <!-- 211130 mobile_none02 삭제 -->
# <li class="policy"><a href="/icare/privacyAgree.jsp">개인정보처리방침</a></li>
# <li class="policy"><a href="/icare/termsAgree.jsp">이용약관</a></li>
# <li class="policy"><a href="/icare/siteMap.jsp">누리집지도</a></li>
# <li class="policy"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1012">오류신고</a></li>
# </ul>
# <div class="address">
# <p class="city">서울특별시청 04524 서울특별시 중구 세종대로 110 <span class="tel">대표전화 : 02-120</span>
# <p class="">Seoul Metropolitan Government all rights reserved</p>
# </p></div>
# </div>
# <span class="foo-logo inquiry"><em class="blind">문의 전화번호 120, 정보를 못찾으셨나요? 120 다산콜센터로 물어보세요!</em></span>
# <div class="mark">
# <ul>
# <li>
# <a href="#none">
# <img alt="엄마 아빠 행복프로젝트" src="/icare/resources/idolbom/img/footer/happiness_banner.png"/>
# </a>
# </li>
# <li>
# <a href="http://www.webwatch.or.kr/Situation/WA_Situation.html?MenuCD=110" rel="noopener" target="_blank" title="새창으로 열림">
# <img alt="과학기술정보통신부 WA(WEB접근성) 품질인증 마크, 웹와치(WebWatch) 2022.03.10 ~ 2023.03.09" src="/icare/resources/idolbom/img/footer/wa.png">
# </img></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div><!--footer_wrap02 END-->
# </footer>
# <!-- /.Footer -->
# <script src="//weblog.eseoul.go.kr/wlo/js/install.js" type="text/javascript"></script>
# </body>
# </html>

# %%
for item in list_html.select('ul li'):
    if item.select_one('p.box_info_p') != None:
        print(item.select_one('a')['onclick'])
        for inside_item in item.select('span'):
            print(inside_item.text.strip().replace('\t', '').replace('\n',':'))
# Out:
# fnView("1009","YC230101","양천구 5호점 우리동네키움센터 (융합형)","");
# 양천구 5호점 우리동네키움센터 (융합형)
# 주소서울특별시 양천구 신월로24길 19
# 연락처:070-:8133-:2463
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:양천구:초등학생
# fnView("1001","KC230101","금천구 4호점 우리동네키움센터(시흥1동)","");
# 금천구 4호점 우리동네키움센터(시흥1동)
# 주소서울특별시 금천구 시흥대로 164
# 연락처:02-:809-:1999
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:금천구:초등학생
# fnView("1001","MP230101","마포구9호점 우리동네키움센터(합정동)","");
# 마포구9호점 우리동네키움센터(합정동)
# 주소서울특별시 마포구 양화로1길 108
# 연락처:02-:322-:2311
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:마포구:초등학생
# fnView("1001","GS221201","강서6호점 화곡8동 우리동네키움센터","");
# 강서6호점 화곡8동 우리동네키움센터
# 주소서울특별시 강서구 강서로5길 50
# 연락처:02-:2602-:1067
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:강서구:초등학생
# fnView("1009","GB221101","강북6호점 우리동네키움센터(융합형)(삼각산동)","");
# 강북6호점 우리동네키움센터(융합형)(삼각산동)
# 주소서울특별시 강북구 삼양로19길 102
# 연락처:02-:988-:1318
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:강북구:초등학생
# fnView("1001","DM221001","동대문구 6호점 우리동네키움센터","");
# 동대문구 6호점 우리동네키움센터
# 주소서울특별시 동대문구 약령시로5길 22
# 연락처:02-:920-:4541
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:동대문구:초등학생
# fnView("1001","GA220501","관악3호점 우리동네키움센터","");
# 관악3호점 우리동네키움센터
# 주소서울특별시 관악구 청림2길 37
# 연락처:02-:877-:3055
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:관악구:초등학생
# fnView("1009","GR221001","구로19호점 우리동네키움센터(항동융합형)","");
# 구로19호점 우리동네키움센터(항동융합형)
# 주소서울특별시 구로구 연동로 191-19
# 연락처:02-:2619-:7942
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:구로구:초등학생
# fnView("1001","DJ221101","동작14호점 우리동네키움센터(상도3동)","");
# 동작14호점 우리동네키움센터(상도3동)
# 주소서울특별시 동작구 상도로15가길 14
# 연락처:02-:6953-:4665
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:동작구:초등학생
# fnView("1001","SP220901","송파18호점 우리동네키움센터(위례동2호점 송파키움센터)","");
# 송파18호점 우리동네키움센터(위례동2호점 송파키움센터)
# 주소서울특별시 송파구 위례북로4길 12
# 연락처:02-:431-:5515
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","EP220902","은평12호점 우리동네키움센터","");
# 은평12호점 우리동네키움센터
# 주소서울특별시 은평구 통일로 627
# 연락처:02-:353-:6184
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:은평구:초등학생
# fnView("1001","EP220901","은평11호점 우리동네키움센터","");
# 은평11호점 우리동네키움센터
# 주소서울특별시 은평구 통일로73길 16
# 연락처:02-:359-:9878
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:은평구:초등학생
# fnView("1008","BP220801","제5호(성북권) 거점형 우리동네키움센터","https://icare.seoul.go.kr/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_3.jsp");
# 제5호(성북권) 거점형 우리동네키움센터
# 주소서울특별시 성북구 회기로3길 17
# 연락처:02-:6956-:7033
# 이용료::::::일 / ::::2,500 원
# 거점형키움센터:성북구:초등학생
# fnView("1009","GB220401","강북3호점 우리동네키움센터(융합형)(삼양동)","");
# 강북3호점 우리동네키움센터(융합형)(삼양동)
# 주소서울특별시 강북구 인수봉로6길 39
# 연락처:02-:989-:9285
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:강북구:초등학생
# fnView("1001","EP220801","은평10호점 우리동네키움센터","");
# 은평10호점 우리동네키움센터
# 주소서울특별시 은평구 은평로 114
# 연락처:02-:2135-:6014
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:은평구:초등학생

# %%
# 송파구 아이돌봄센터 내역을 가져온뒤에 해당 페이지에 있는 코드값을 파싱하여 코드표를 준비한다
LIST_BODY = [('q_hiddenVal', 1),('q_searchAt', 'Y')
             ,('q_moreSvc', 1001), ('q_tabVal', 1001), ('q_svcClCode', 1001), ('q_atdrcCode', 11710)]
list_res = web_request(REQ_POST, LIST_PAGE, LIST_BODY)
list_html = bs(list_res['text'], "html.parser")

# %%
def FacilitieInfoParser(res_html):
    for item in res_html.select('ul li'):
    if item.select_one('p.box_info_p') != None:
        print(item.select_one('a')['onclick'])
        for inside_item in item.select('span'):
            print(inside_item.text.strip().replace('\t', '').replace('\n',':'))

# %%
TOTAL_BODY
# Out:
# [('q_hiddenVal', '1'),
#  ('q_searchAt', 'Y'),
#  ('q_rowPerPage', '15'),
#  ('q_currPage', '1'),
#  ('q_tabVal', '1001'),
#  ('q_moreSvc', '1001')]

# %%
for item in 탭목록:
    TOTAL_BODY = copy.deepcopy(TEMPLATE_BODY)
    TOTAL_BODY.append((item['key'],item['value']))
    TOTAL_BODY.append(('q_moreSvc',item['value']))
    TOTAL_RES = web_request(REQ_POST, LIST_PAGE, TOTAL_BODY)
    total_html = bs(TOTAL_RES['text'], "html.parser")
    total_cnt = total_html.select_one('p.board_info').text
    total_cnt = total_cnt[total_cnt.index('전체'):total_cnt.index('건')]
    total_cnt = re.sub(r'[^0-9]', '', total_cnt)
    total_pages = math.ceil(int(total_cnt)/15)
    print(total_html)
    break
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/icare/resources/idolbom/img/main/favicon.ico" rel="SHORTCUT ICON"/>
# <title>
#
#
# 		맞춤형정보 : HOME &gt; 홍보·자료 &gt; 돌봄 정보찾기 &gt; 맞춤형정보
#
# </title>
# <!-- customize -->
# <link href="/icare/resources/openworks4/css/openworks4-custom.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">var CTX_PATH="";</script>
# <!-- jquery core -->
# <!-- <script type="text/javascript" src="/icare/resources/libs/jquery/jquery-1.11.2.min.js"></script> -->
# <script src="/icare/resources/idolbom/js/lib/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="/icare/resources/libs/jquery-ui-1.11.3.custom/jquery-ui.min.js" type="text/javascript"></script>
# <!-- 설정 동기화 -->
# <script src="/icare/component/js/ND_globalConfig.do" type="text/javascript"></script>
# <script src="/icare/component/js/ND_massageConfig.do" type="text/javascript"></script>
# <!-- Openworks 공통 메소드 -->
# <script src="/icare/resources/openworks4/js/openworks.global.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.message.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.initialize.js" type="text/javascript"></script>
# <link href="/icare/resources/idolbom/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/layout_media.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/main_new.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/sub_content.css" rel="stylesheet" type="text/css"/>
# <link href="/icare/resources/idolbom/css/sub_content_media.css" rel="stylesheet" type="text/css"/>
# <script src="/icare/resources/idolbom/js/lib/bxslider.min.js"></script>
# <script src="/icare/resources/idolbom/js/layout.js"></script>
# <script src="/icare/resources/idolbom/js/sub.js"></script>
# <link href="/icare/resources/idolbom/css/add_200221.css" rel="stylesheet" type="text/css"/><!-- 20200221 팝업 css -->
# <link href="/icare/resources/idolbom/css/add_sns.css" rel="stylesheet" type="text/css"/><!-- 20200422 sns 추가 css -->
# <script src="https://www.seoul.go.kr/seoulgnb/gnb.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.form.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.ui.js" type="text/javascript"></script>
# <link href="/icare/resources/libs/fancybox-2.1.5/css/jquery.fancybox.css" rel="stylesheet" type="text/css">
# <script src="/icare/resources/libs/fancybox-2.1.5/js/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/icare/resources/openworks4/js/openworks.modal.js" type="text/javascript"></script>
# <script src="/icare/resources/libs/form-3.51.0/jquery.form.js" type="text/javascript"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-154136673-1"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-154136673-1');
# </script>
# <!-- 모니터링 -->
# <script type="text/javascript">
# 	var _bwa = [];
# 	_bwa.push(['setCollectorUrl', 'https://www.zesinc.co.kr/api/collector/icare']);
# 	_bwa.push(['setCustomerId', 'icare']);
# 	var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
# 	g.type='text/javascript';
# 	g.src="/icare/resources/openworks4/js/blueworksWebAgent-2_1-min.js";
# 	g.async=g.defer=true;
# 	s.parentNode.insertBefore(g, s);
# </script>
# <script>
# 	/* 초기화 */
# 	$(document).ready(function() {
# 		window.onload = function() {
# 			Yjs.Gnb.init("G248", "seoul-common-gnb");
# 		};
# 	});
#
# 	/* 개발 로그인 */
# 	/* var devLoginPop = function() {
# 		$().opmodal({
# 			href : "/icare/user/mypage/PD_devLoginForm.do",
# 			width : 500
# 		});
# 	} */
# </script>
# <script type="text/javascript">
#     var CTX_PATH="";
# </script>
# <script type="text/javascript">
# 		//<![CDATA[
#
# 		/* 공통 초기화 기능 */
# 		$(document).ready(function() {
#
# 			$("#q_searchVal").keypress(function (e) {
# 				if (e.which == 13){
# 					searchBtn();
# 				}
# 			});
#
# 			// 이용연령 전체 선택
# 			$("#age_all").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("input:checkbox[id^=age_]").prop("checked", true);
# 				} else {
# 					$("input:checkbox[id^=age_]").prop("checked", false);
# 				}
# 			});
#
# 			// 모바일 버전 일 때 이용연령 선택시 서비스 분류 노출
# 			var windowWidth = $( window ).width();
# 			if(windowWidth < 767) {
# 				$("input:checkbox[id^=age_]").click(function(){
# 					var checked = $(this).prop("checked");
# 					if(checked){
# 						$(".service_select02 > h3").parent().addClass('open');
# 					}else{
# 						var num = $("input:checkbox[id^=age_]:checked").length;
# 						if(num == 0){
# 							$(".service_select02 > h3").parent().removeClass('open');
# 						}
# 					}
# 				});
# 			};
#
# 			// 이용연령 선택
# 			$("input:checkbox[id^=age_]").click(function(){
# 				var checked = $(this).prop("checked");
# 				var num = $("input:checkbox[id^=age_]").not("#age_all").length;
# 				var num2 = $("input:checkbox[id^=age_]:checked").not("#age_all").length;
# 				if(num == num2){
# 					$("input:checkbox[id^=age_]").prop("checked", true);
# 				}
# 			});
#
# 			// 기타시설
# 			$("input:checkbox[name=q_fcltyCl]").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("#fcltyCl").val(1007);
# 					$("#fcltyCl").prop("disabled", false);
# 				} else {
# 					if($("input:checkbox[name=q_fcltyCl]:checked").length == 0){
# 						$("#fcltyCl").prop("disabled", true);
# 					}else{
# 						$("#fcltyCl").val();
# 					}
# 				}
# 			});
#
# 			//기타시설이 하나라도 체크되어 있을 때
# 			if($("input:checkbox[name=q_fcltyCl]:checked").length > 0){
# 				$("#fcltyCl").val(1007);
# 				$("#fcltyCl").prop("disabled", false);
# 			} else {
# 				$("#fcltyCl").prop("disabled", true);
# 			}
#
# 			//지역 전체 선택
# 			$("#area_all").click(function(){
# 				var checked = $(this).prop("checked");
# 				if(checked) {
# 					$("input:checkbox[id^=area_]").prop("checked", true);
# 				} else {
# 					$("input:checkbox[id^=area_]").prop("checked", false);
# 				}
# 			});
#
# 			//지역 일부 선택
# 			$("input:checkbox[id^=area_]").click(function(){
# 				var num = $("input:checkbox[id^=area_]").not("#area_all").length;
# 				var num2 = $("input:checkbox[id^=area_]:checked").not("#area_all").length;
# 				if(num == num2){
# 					$("input:checkbox[id=area_all]").prop("checked", true);
# 				}else{
# 					$("input:checkbox[id=area_all]").prop("checked", false);
# 				}
# 			});
# 		});
#
# 		// 검색
# 		function searchBtn(){
# 			var num  = $("input:checkbox[id^=fac_0]:checked").length;
# 			var num2 = $("input:checkbox[id^=fac_1]:checked").length;
# 			var num3 = $("input:checkbox[id^=fac_2]:checked").length;
#
# 			// 구분값 하나 이상 선택
# 			if (num + num2 + num3 == 0) {
# 				alert("검색조건(시설 또는 교육)을 선택하세요");
# 				return false;
# 			} else {
# 				$("#q_currPage").val(1);
# 				$("#q_searchAt").val("Y");
# 				$("#q_tabVal").val("");
# 				$("#q_moreSvc").val("");
# 				$("#searchForm").submit();
# 			}
# 		};
#
# 		// 초기화
# 		function searchReset(){
# 			$("#searchForm").find("input").prop("disabled", true);
# 			$("#searchForm").submit();
# 		};
#
# 		// 페이지이동
# 		function jsMovePage(page){
# 			$("#q_currPage").val(page);
# 			$("#searchForm").submit();
# 		};
#
# 		// 탭이동
# 		var fnTabMove = function(tabVal) {
# 			var checked = "";
# 			if (tabVal == '1008') {        // 교육
# 				$("input:checkbox[id^=fac_2]:checked").each(function(i) {
# 					if (i != 0) {
# 						checked += ',';
# 					}
# 					checked += $(this).val();
# 				});
# 				$("#q_moreSvc").val(checked);
# 			} else if (tabVal == '1007') { // 지역보육정보
# 				$("input:checkbox[id^=fac_1]:checked").each(function(i) {
# 					if ($(this).val() != '2001') {
# 						checked = tabVal;
# 					} else {
# 						if (i != 0) {
# 							checked += ',';
# 						}
# 						checked += $(this).val();
# 					}
# 				});
# 				$("#q_moreSvc").val(checked);
# 			} else {
# 				$("#q_moreSvc").val(tabVal);
# 			}
# 			$("#q_tabVal").val(tabVal);
#
# 			$("#q_currPage").val(1);
# 			$("#q_searchAt").val("Y");
# 			$("#searchForm").submit();
# 		}
#
# 		// 더보기 버튼
# 		var moreBtn = function(svcClCode, fcltyClCode, trgetClCode) {
# 			if (svcClCode == "1008" || svcClCode == "1009") {
# 				$("#q_moreSvc").val("1001");
# 				$("#q_tabVal").val("1001");
# 			} else if (svcClCode == "1007") {
# 				$("#q_fcltyClCode").val(fcltyClCode);
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val(svcClCode);
# 			} else if (svcClCode == "2001") {
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val("1007");
# 			} else if (svcClCode == "2003") {
# 				if (trgetClCode == '1001') {
# 					$("#q_moreSvc").val("2002");
# 				} else {
# 					$("#q_moreSvc").val(svcClCode);
# 				}
# 				$("#q_tabVal").val("1008");
# 			} else {
# 				$("#q_moreSvc").val(svcClCode);
# 				$("#q_tabVal").val(svcClCode);
# 			}
# 			$("#q_currPage").val(1);
# 			$("#q_searchAt").val("Y");
# 			$("#searchForm").submit();
# 		}
#
# 		// 상세보기
# 		var fnView = function(svcClCode, fcltyId, fcltyNm, siteUrl) {
# 			if (svcClCode == "1005" || svcClCode == "2003") {
# 				window.open(siteUrl, "_blank");
# 			} else if (svcClCode == "1007" || svcClCode == "2003") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "2001") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#q_gubun").val("1001");
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "2002") {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_clturEventEtcSn").val(fcltyId);
# 				$("#q_gubun").val("1002");
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			} else if (svcClCode == "1006") {
# 				if (fcltyNm.indexOf("휴일보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("시간보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/night_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("365열린어린이집") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
# 				} else if (fcltyNm.indexOf("거점형시간연장보육") > 0) {
# 					window.open("https://iseoul.seoul.go.kr/portal/reservation/dailyOpenPreschoolMiddle.do", "_blank");
# 				} else {
# 					window.open("https://iseoul.seoul.go.kr/portal/info/preSchoolList.do", "_blank");
# 				}
# 			} else if (svcClCode == "1008") {
# 				location.href = siteUrl;
# 			} else {
# 				$("#q_fclty").val(svcClCode);
# 				$("#q_fcltyId").val(fcltyId);
# 				$("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
# 				$("#searchForm").submit();
# 			}
# 		}
#
# 		//]]>
# 	</script>
# <script type="text/javascript">
#     var anlzSessionId = "50C0DCD86A0AB05694DB0AC4C2920D61.tomcat2";
#     var anlzClientIp = "211.234.198.84";
#     var anlzMenuCode = "dolbomMENU4_1_1";
# </script>
# <script src="/icare/resources/openworks4/js/analyze/tracker.js" type="text/javascript"></script>
# </link></head>
# <body>
# <div id="skipNav">
# <p><a href="#container">본문바로가기</a></p>
# <p><a href="#gnb">주메뉴바로가기</a></p>
# </div>
# <div id="mask"></div>
# <div id="seoul-common-gnb"></div>
# <div class="header">
# <div class="header_con">
# <div id="gnb">
# <div class="header_inner">
# <h1 class="logo">
# <a href="javascript:goMain();" title="메인으로"><img alt="서울케어 우리동네키움포털" src="/icare/resources/idolbom/img/common/logo_new.png"/></a>
# </h1>
# <div class="m_gnbBtn">
# <button class="m_gnbOpen" type="button"><img alt="메뉴열기" src="/icare/resources/idolbom/img/common/m_gnb.png"/></button>
# <button class="m_gnbClose" type="button"><img alt="메뉴닫기" src="/icare/resources/idolbom/img/common/m_gnb_close.png"/></button>
# </div>
# <div class="gnb_wrap">
# <div class="m_login">
# <ul class="btn">
# <li class="login_btn"><a href="/icare/login/BD_loginForm.do">로그인</a></li>
# <li class="join_btn"><a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">회원가입</a></li>
# </ul>
# <div class="m_sns">
# <a class="blog" href="https://blog.naver.com/seoulkium" title="우리동네키움센터 네이버블로그 새창열림"><span>우리동네키움센터<br/>네이버블로그</span></a>
# <a class="youtube" href="https://www.youtube.com/channel/UChV3e-MPtIwdEU6Md14Bo3A" title="우리동네키움튜브 새창열림"><span>우리동네키움튜브</span></a>
# </div>
# </div>
# <ul>
# <li class="m_gnb_on">
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="초등돌봄 바로가기">초등돌봄</a>
# <a class="mn" href="#none;">초등돌봄</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="일반/융합형 우리동네키움센터 바로가기">일반/융합형 우리동네키움센터</a>
# <a class="mn" href="#none;">일반/융합형 우리동네키움센터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="서비스소개 바로가기">서비스소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=2" title="이용안내 바로가기">이용안내</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=3" title="센터연락처(서울소재) 바로가기">센터연락처(서울소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=4" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_1.jsp" title="거점형 키움센터 바로가기">거점형 키움센터</a>
# <a class="mn" href="#none;">거점형 키움센터</a>
# <ul>
# <li>
# <a href="#none;" title="열기">거점1호 (노원·도봉권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_1/dolbomMENU1_2_1_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점2호 (동작권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_2/dolbomMENU1_2_2_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점3호 (종로·서대문권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_3/dolbomMENU1_2_3_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">거점5호 (성북권)</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_1.jsp" title="인사말 바로가기">인사말</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_2.jsp" title="비전 및 연혁 바로가기">비전 및 연혁</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_3.jsp" title="시설소개 바로가기">시설소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_4.jsp" title="주요사업 및 운영조직도 바로가기">주요사업 및 운영조직도</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_2/dolbomMENU1_2_5/dolbomMENU1_2_5_5.jsp" title="오시는길 및 이용안내 바로가기">오시는길 및 이용안내</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=1" title="지역아동센터 바로가기">지역아동센터</a>
# <a class="mn" href="#none;">지역아동센터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=2" title="이용안내 바로가기">이용안내</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=3" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectLocalCenterContactList.do?q_tap=4" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_4/dolbomMENU1_4_1.jsp" title="청소년방과후아카데미 바로가기">청소년방과후아카데미</a>
# <a class="mn" href="#none;">청소년방과후아카데미</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_4/dolbomMENU1_4_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCenterContactList.do?q_gubunCd=1010" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU1/dolbomMENU1_5/dolbomMENU1_5_1.jsp" title="초등돌봄교실 바로가기">초등돌봄교실</a>
# <a class="mn" href="#none;">초등돌봄교실</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU1/dolbomMENU1_5/dolbomMENU1_5_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCenterContactList.do?q_gubunCd=1005" title="초등돌봄 연락처(서울 소재) 바로가기">초등돌봄 연락처(서울 소재)</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="영유아돌봄 바로가기">영유아돌봄</a>
# <a class="mn" href="#none;">영유아돌봄</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="공동육아방 바로가기">공동육아방</a>
# <a class="mn" href="#none;">공동육아방</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=2" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=3" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=1" title="공동육아나눔터 바로가기">공동육아나눔터</a>
# <a class="mn" href="#none;">공동육아나눔터</a>
# <ul>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=2" title="센터 연락처(서울 소재) 바로가기">센터 연락처(서울 소재)</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1004&amp;q_tap=3" title="자치구 담당부서 바로가기">자치구 담당부서</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_1.jsp" title="아이돌봄 서비스 바로가기">아이돌봄 서비스</a>
# <a class="mn" href="#none;">아이돌봄 서비스</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_1.jsp" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU2/dolbomMENU2_3/dolbomMENU2_3_2.jsp" title="서비스 제공기관 바로가기">서비스 제공기관</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=1" title="우리동네 보육반장 바로가기">우리동네 보육반장</a>
# <a class="mn" href="#none;">우리동네 보육반장</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=1" title="서비스 소개 바로가기">서비스 소개</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=2" title="우리동네 꼼꼼 육아정보 바로가기">우리동네 꼼꼼 육아정보</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1013&amp;q_tab=3" title="우리동네보육반장 연락처 바로가기">우리동네보육반장 연락처</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1005" title="활동소식 바로가기">활동소식</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 바로가기">서울형 키즈카페</a>
# <a class="mn" href="#none;">서울형 키즈카페</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 소개 바로가기">서울형 키즈카페 소개</a>
# <a class="mn" href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 소개 바로가기">서울형 키즈카페 소개</a>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/kidsCafe/BD_selectKidsCafeList.do" title="서울형 키즈카페 안내 바로가기">서울형 키즈카페 안내</a>
# <a class="mn" href="/icare/user/kidsCafe/BD_selectKidsCafeList.do" title="서울형 키즈카페 안내 바로가기">서울형 키즈카페 안내</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약신청 바로가기">예약신청</a>
# <a class="mn" href="#none;">예약신청</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="돌봄 서비스 바로가기">돌봄 서비스</a>
# <a class="mn" href="#none;">돌봄 서비스</a>
# <ul>
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약안내 바로가기">예약안내</a>
# </li>
# <li>
# <a href="#none;" title="열기">거점형키움센터 예약</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_2/dolbomMENU3_1_2_1.jsp" title="일시·긴급돌봄 서비스 바로가기">일시·긴급돌봄 서비스</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_2/dolbomMENU3_1_2_2.jsp" title="아픈아이 돌봄 서비스 바로가기">아픈아이 돌봄 서비스</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/icare/user/careResve/BD_selectChilCareResveList.do" title="우리동네키움센터 예약 바로가기">우리동네키움센터 예약</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_1/dolbomMENU3_2_1_1.jsp" title="체험 서비스 바로가기">체험 서비스</a>
# <a class="mn" href="#none;">체험 서비스</a>
# <ul>
# <li>
# <a href="#none;" title="열기">창의체험 활동</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_1/dolbomMENU3_2_1_1.jsp" title="문화예술창작활동 소개 바로가기">문화예술창작활동 소개</a>
# </li>
# <li>
# <a href="/icare/user/chilProgrm/orgideaExprnCtzn/BD_selectOrgideaExprnCtznList.do?q_progrmCl=1000&amp;q_placeCode=100" title="문화예술창작활동 신청 바로가기">문화예술창작활동 신청</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="#none;" title="열기">특화프로그램 활동</a>
# <ul class="dep4">
# <li>
# <a href="/icare/dolbomMENU3/dolbomMENU3_2/dolbomMENU3_2_2/dolbomMENU3_2_2_1.jsp" title="특화프로그램 소개 바로가기">특화프로그램 소개</a>
# </li>
# <li>
# <a href="/icare/user/chilProgrm/orgideaExprnCtzn/BD_selectOrgideaExprnCtznList.do?q_progrmCl=2000&amp;q_placeCode=100" title="특화프로그램 신청 바로가기">특화프로그램 신청</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="홍보·자료 바로가기">홍보·자료</a>
# <a class="mn" href="#none;">홍보·자료</a>
# <div class="gnb_2dep">
# <ul class="gnb_sub_con">
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 정보찾기 바로가기">돌봄 정보찾기</a>
# <a class="mn" href="#none;">돌봄 정보찾기</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 서비스 문의처 바로가기">돌봄 서비스 문의처</a>
# </li>
# <li>
# <a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형정보 바로가기">맞춤형정보</a>
# </li>
# <li>
# <a href="/icare/dolbomMENU4/dolbomMENU4_1/dolbomMENU4_1_2.jsp" title="아이돌봄지도서비스 바로가기">아이돌봄지도서비스</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="알림방 바로가기">알림방</a>
# <a class="mn" href="#none;">알림방</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="공지사항 바로가기">공지사항</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1003" title="우리동네키움센터소식 바로가기">우리동네키움센터소식</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1021" title="채용소식 바로가기">채용소식</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1025" title="고시/공고 바로가기">고시/공고</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="홍보방 바로가기">홍보방</a>
# <a class="mn" href="#none;">홍보방</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="동영상 바로가기">동영상</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1004" title="갤러리 바로가기">갤러리</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1030" title="프로젝트기반배움(PBL) 운영사례 바로가기">프로젝트기반배움(PBL) 운영사례</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="자료실 바로가기">자료실</a>
# <a class="mn" href="#none;">자료실</a>
# <ul>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="키움센터 뉴스레터 바로가기">키움센터 뉴스레터</a>
# </li>
# <li>
# <a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1018" title="자료실 바로가기">자료실</a>
# </li>
# </ul>
# </li>
# <li>
# <a class="pc_mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a>
# <a class="mn" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# <ul class="util_menu">
# <li class="login">
# <a href="/icare/login/BD_loginForm.do">
# 									로그인
# 								</a>
# </li>
# <li class="join">
# <a href="https://iseoul.seoul.go.kr/portal/login/joinGeneral.do?returnurl=/icare/index.do">
# 									회원가입
# 								</a>
# </li>
# </ul>
# </div><!--gnb_wrap END-->
# <div class="m_gnb_bg"></div>
# </div><!--gnb END-->
# </div><!--header_wrap END-->
# </div><!--//header END-->
# <div class="location">
# <div class="location_wrap">
# <ul>
# <li class="home">
# <a href="/icare/index.do"><img alt="메인으로" src="/icare/resources/idolbom/img/common/sta_home.png"/></a>
# </li>
# <li class="m_location"><!--모바일쪽 로케이션-->
# <p>맞춤형정보</p>
# </li>
# <li class="location_bar main"><!--pc쪽 로케이션-->
# <a class="mainMenu" href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do;jsessionid=50C0DCD86A0AB05694DB0AC4C2920D61.tomcat2" title="주메뉴 선택, 축소됨">홍보·자료</a>
# <ul>
# <li><a href="/icare/user/fcltyInfoManage/BD_selectCareCenterContactList.do?q_tap=1" title="초등돌봄 바로가기">초등돌봄</a></li>
# <li><a href="/icare/user/fcltyInfoManage/BD_selectCopertnChldcrContactList.do?q_svcClCode=1002&amp;q_tap=1" title="영유아돌봄 바로가기">영유아돌봄</a></li>
# <li><a href="/icare/dolbomMENU5/dolbomMENU5_1.jsp" title="서울형 키즈카페 바로가기">서울형 키즈카페</a></li>
# <li><a href="/icare/dolbomMENU3/dolbomMENU3_1/dolbomMENU3_1_1.jsp" title="예약신청 바로가기">예약신청</a></li>
# <li class="lb_on"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="홍보·자료 바로가기">홍보·자료</a></li>
# </ul>
# </li>
# <li class="location_bar sub"><!--pc쪽 로케이션 2depth-->
# <a class="subMenu" href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="하위메뉴 선택, 축소됨">돌봄 정보찾기</a>
# <ul>
# <li class="lb_on"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 정보찾기 바로가기">돌봄 정보찾기</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1001" title="알림방 바로가기">알림방</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1019" title="홍보방 바로가기">홍보방</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1027" title="자료실 바로가기">자료실</a></li>
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1011" title="자주묻는질문 바로가기">자주묻는질문</a></li>
# </ul>
# </li>
# <li class="location_bar sub"><!--pc쪽 로케이션 3depth-->
# <a class="subMenu" href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="하위메뉴 선택, 축소됨">맞춤형정보</a>
# <ul>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1026" title="돌봄 서비스 문의처 바로가기">돌봄 서비스 문의처</a></li>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li class="lb_on"><a href="/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do" title="맞춤형정보 바로가기">맞춤형정보</a></li>
# <!-- 사용자등급이 필요한 메뉴는 세션에 등급코드와 비교하여 표출 -->
# <li><a href="/icare/dolbomMENU4/dolbomMENU4_1/dolbomMENU4_1_2.jsp" title="아이돌봄지도서비스 바로가기">아이돌봄지도서비스</a></li>
# </ul>
# </li>
# </ul>
# </div><!--location_wrap END-->
# </div><!--location END-->
# <div class="sub_container" id="container">
# <div class="sub_content">
# <h2 class="sub_title01 mb_55">맞춤형 정보 서비스</h2>
# <form action="BD_selectFcltyInfoManageList.do" class="form-horizontal" id="searchForm" method="post" name="searchForm">
# <input id="q_clturEventEtcSn" name="q_clturEventEtcSn" type="hidden" value=""/>
# <input id="q_fcltyId" name="q_fcltyId" type="hidden" value=""/>
# <input id="q_fclty" name="q_fclty" type="hidden" value=""/>
# <input id="q_gubun" name="q_gubun" type="hidden" value=""/>
# <input id="q_eduProgramVal" name="q_eduProgramVal" type="hidden" value=""/>
# <input id="q_hiddenVal" name="q_hiddenVal" type="hidden" value="1"/>
# <input id="q_fcltyClCode" name="q_fcltyClCode" type="hidden" value=""/>
# <input id="q_searchAt" name="q_searchAt" type="hidden" value="Y"/>
# <input id="q_moreSvc" name="q_moreSvc" type="hidden" value="1001"/>
# <input id="q_tabVal" name="q_tabVal" type="hidden" value="1001"/>
# <div class="table_ty01 m_table_ty01 table_ty_01_pd">
# <table class="center">
# <caption>맞춤형 정보 서비스 검색폼(구분(돌봄시설,지역보육정보,교육),이용연령,자치구,검색어)</caption>
# <colgroup>
# <col style="width: 3%"/>
# <col style="width: 12%"/>
# <col style="width: auto"/>
# </colgroup>
# <tbody>
# <tr>
# <th rowspan="3" scope="row">구분</th>
# <th scope="row">돌봄시설</th>
# <td>
# <ul class="fixe_chk">
# <li class="fclty"><input id="fac_01" name="q_svcClCode" type="checkbox" value="1001"/><label for="fac_01">우리동네 키움센터</label></li>
# <li class="fclty"><input id="fac_02" name="q_svcClCode" type="checkbox" value="1003"/><label for="fac_02">지역 아동센터</label></li>
# <li class="fclty"><input id="fac_03" name="q_svcClCode" type="checkbox" value="1005"/><label for="fac_03">초등 돌봄교실</label></li>
# <li class="fclty"><input id="fac_04" name="q_svcClCode" type="checkbox" value="1002"/><label for="fac_04">공동육아방</label></li>
# <li class="fclty"><input id="fac_05" name="q_svcClCode" type="checkbox" value="1004"/><label for="fac_05">공동육아 나눔터</label></li>
# <li class="fclty"><input id="fac_07" name="q_svcClCode" type="checkbox" value="1010"/><label for="fac_07">청소년방과후아카데미</label></li>
# <li class="fclty"><input id="fac_06" name="q_svcClCode" type="checkbox" value="1006"/><label for="fac_06">영·유아 보육시설</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th scope="row">지역보육정보</th>
# <td>
# <input id="fcltyCl" name="q_svcClCode" type="hidden" value="">
# <ul class="area_chk">
# <li><input id="fac_10" name="q_fcltyCl" type="checkbox" value="1001"/><label for="fac_10">야외 시설</label></li>
# <li><input id="fac_11" name="q_fcltyCl" type="checkbox" value="1003"/><label for="fac_11">도서관</label></li>
# <li><input id="fac_12" name="q_fcltyCl" type="checkbox" value="1004"/><label for="fac_12">의료 시설</label></li>
# <li><input id="fac_13" name="q_fcltyCl" type="checkbox" value="1002"/><label for="fac_13">체험 시설</label></li>
# <li><input id="fac_14" name="q_fcltyCl" type="checkbox" value="1005"/><label for="fac_14">관공서</label></li>
# </ul>
# </input></td>
# </tr>
# <tr>
# <th scope="row">교육</th>
# <td>
# <ul class="fixe_chk">
# <li><input id="fac_21" name="q_clturEvent" type="checkbox" value="2002"/><label for="fac_21">초등생 교육 프로그램</label></li>
# <li><input id="fac_22" name="q_clturEvent" type="checkbox" value="2003"/><label for="fac_22">영·유아 교육 프로그램</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="2" scope="row">이용연령</th>
# <td>
# <ul class="area_chk">
# <li><input id="age_all" name="q_ageSeCode" type="checkbox" value="1000"/><label for="age_all">전체</label></li>
# <li><input id="age_01" name="q_ageSeCode" type="checkbox" value="1001"/><label for="age_01">영·유아</label></li>
# <li><input id="age_02" name="q_ageSeCode" type="checkbox" value="1002"/><label for="age_02">유치원생</label></li>
# <li><input id="age_03" name="q_ageSeCode" type="checkbox" value="1003"/><label for="age_03">초등학생</label></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th colspan="2" scope="row">자치구</th>
# <td>
# <ul class="area_chk">
# <li class="area_li"><input id="area_all" name="q_atdrcCode" type="checkbox" value="1000"/><label for="area_all">전체</label></li>
# <li class="area_li"><input id="area_1" name="q_atdrcCode" type="checkbox" value="11680"/><label for="area_1">강남구</label></li>
# <li class="area_li"><input id="area_2" name="q_atdrcCode" type="checkbox" value="11740"/><label for="area_2">강동구</label></li>
# <li class="area_li"><input id="area_3" name="q_atdrcCode" type="checkbox" value="11305"/><label for="area_3">강북구</label></li>
# <li class="area_li"><input id="area_4" name="q_atdrcCode" type="checkbox" value="11500"/><label for="area_4">강서구</label></li>
# <li class="area_li"><input id="area_5" name="q_atdrcCode" type="checkbox" value="11620"/><label for="area_5">관악구</label></li>
# <li class="area_li"><input id="area_6" name="q_atdrcCode" type="checkbox" value="11215"/><label for="area_6">광진구</label></li>
# <li class="area_li"><input id="area_7" name="q_atdrcCode" type="checkbox" value="11530"/><label for="area_7">구로구</label></li>
# <li class="area_li"><input id="area_8" name="q_atdrcCode" type="checkbox" value="11545"/><label for="area_8">금천구</label></li>
# <li class="area_li"><input id="area_9" name="q_atdrcCode" type="checkbox" value="11350"/><label for="area_9">노원구</label></li>
# <li class="area_li"><input id="area_10" name="q_atdrcCode" type="checkbox" value="11320"/><label for="area_10">도봉구</label></li>
# <li class="area_li"><input id="area_11" name="q_atdrcCode" type="checkbox" value="11230"/><label for="area_11">동대문구</label></li>
# <li class="area_li"><input id="area_12" name="q_atdrcCode" type="checkbox" value="11590"/><label for="area_12">동작구</label></li>
# <li class="area_li"><input id="area_13" name="q_atdrcCode" type="checkbox" value="11440"/><label for="area_13">마포구</label></li>
# <li class="area_li"><input id="area_14" name="q_atdrcCode" type="checkbox" value="11410"/><label for="area_14">서대문구</label></li>
# <li class="area_li"><input id="area_15" name="q_atdrcCode" type="checkbox" value="11650"/><label for="area_15">서초구</label></li>
# <li class="area_li"><input id="area_16" name="q_atdrcCode" type="checkbox" value="11200"/><label for="area_16">성동구</label></li>
# <li class="area_li"><input id="area_17" name="q_atdrcCode" type="checkbox" value="11290"/><label for="area_17">성북구</label></li>
# <li class="area_li"><input id="area_18" name="q_atdrcCode" type="checkbox" value="11710"/><label for="area_18">송파구</label></li>
# <li class="area_li"><input id="area_19" name="q_atdrcCode" type="checkbox" value="11470"/><label for="area_19">양천구</label></li>
# <li class="area_li"><input id="area_20" name="q_atdrcCode" type="checkbox" value="11560"/><label for="area_20">영등포구</label></li>
# <li class="area_li"><input id="area_21" name="q_atdrcCode" type="checkbox" value="11170"/><label for="area_21">용산구</label></li>
# <li class="area_li"><input id="area_22" name="q_atdrcCode" type="checkbox" value="11380"/><label for="area_22">은평구</label></li>
# <li class="area_li"><input id="area_23" name="q_atdrcCode" type="checkbox" value="11110"/><label for="area_23">종로구</label></li>
# <li class="area_li"><input id="area_24" name="q_atdrcCode" type="checkbox" value="11140"/><label for="area_24">중구</label></li>
# <li class="area_li"><input id="area_25" name="q_atdrcCode" type="checkbox" value="11260"/><label for="area_25">중랑구</label></li>
# </ul>
# </td>
# </tr>
# <tr class="table_ty_01_pd_02">
# <th colspan="2" scope="row">검색어</th>
# <td>
# <ul class="service_search_btn" style="margin-top:0px;">
# <li class="search_input"><input id="q_searchVal" name="q_searchVal" placeholder="검색하실 우리동네키움센터명을 입력해주세요." title="키움센터명 검색어 입력" type="text" value=""/></li>
# </ul>
# </td>
# </tr>
# <tr class="table_ty_01_pd_02">
# <td colspan="3">
# <ul class="service_search_btn" style="margin-top:0px; float: right;">
# <li class="search_btn"><a href="#" onclick="searchBtn(); return false;"><img alt="검색버튼" src="/icare/resources/idolbom/img/sub/search_icon.png"/>검색</a></li>
# <li class="reset_btn"><a href="#" onclick="searchReset(); return false;"><img alt="초기화버튼" src="/icare/resources/idolbom/img/sub/reset_icon.png"/>초기화</a></li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="mt_10">
# <ul class="tab tab_li_10-1 m_tab_9">
# <li><a href="#" onclick="fnTabMove(''); return false;">전체</a></li>
# <li class="tab_on"><a href="#" onclick="fnTabMove('1001'); return false;">우리동네 키움센터</a></li>
# <li><a href="#" onclick="fnTabMove('1003'); return false;">지역 아동센터</a></li>
# <li><a href="#" onclick="fnTabMove('1005'); return false;">초등돌봄교실</a></li>
# <li><a href="#" onclick="fnTabMove('1002'); return false;">공동육아방</a></li>
# <li><a href="#" onclick="fnTabMove('1004'); return false;">공동육아 나눔터</a></li>
# <li><a href="#" onclick="fnTabMove('1010'); return false;">방과후 아카데미</a></li>
# <li><a href="#" onclick="fnTabMove('1006'); return false;">영.유아 보육시설</a></li>
# <li><a href="#" onclick="fnTabMove('1008'); return false;">교육</a></li>
# <li><a href="#" onclick="fnTabMove('1007'); return false;">지역보육정보</a></li>
# </ul>
# </div>
# <div class="board_box_ty02 mt_40">
# <p class="board_info">
# <span class="sr-only">페이지당 목록갯수 선택</span>
#
#
#
#
# 						전체 0건 (1페이지 / 전체 1페이지)
#
#
#
#
#
#
#
# 	<input id="q_rowPerPage" name="q_rowPerPage" type="hidden" value="15">
# <input id="q_currPage" name="q_currPage" type="hidden" value="1">
# <input id="q_sortName" name="q_sortName" type="hidden" value="">
# <input id="q_sortOrder" name="q_sortOrder" type="hidden" value="">
# </input></input></input></input></p>
# <ul>
# <div style="text-align:center; color:#555555; padding-top: 17px;">
# <span class="nodata-msg text-warning">해당 검색조건(시설 또는 교육)에 해당하는 데이터가 없습니다.</span>
# </div>
# </ul>
# </div><!--board_box_ty02 END-->
# </form>
# <div class="paging mt_40">
# <ul>
# <li class="paging_num paging_num_on"><a href="#" onclick="return false;" title="현재 1 페이지">1</a></li>
# </ul>
# </div>
# <!-- go top -->
# <span class="go-top"><a class="top" href="#"><img alt="top으로 바로가기" src="/icare/resources/idolbom/img/main/btn_top.png"/></a></span>
# <!-- //go top -->
# </div><!--sub_content END-->
# </div><!--container END-->
# <!-- Footer -->
# <footer class="footer" id="footer">
# <div class="footer_wrap">
# <div class="inner">
# <div class="footer-link">
# <!-- <div class="sns sns-new">
# 						RSS연동 후 주석 제거
# 						<a href="#" class="rss">RSS</a>
# 						<a href="https://www.facebook.com/seoul.kr" class="fb" target="_blank" title="새창열림" onclick="se_click_logging('https://www.facebook.com/seoul.kr?tr_code=sns',location.href);">페이스북</a>
# 						<a href="http://twitter.com/seoulmania" class="tw" target="_blank" title="새창열림" onclick="se_click_logging('http://twitter.com/seoulmania?tr_code=sns',location.href);">트위터</a>
# 						<a href="http://www.instagram.com/seoul_official" class="ins" target="_blank" title="새창열림" onclick="se_click_logging('http://www.instagram.com/seoul_official?tr_code=sns',location.href);">인스타그램</a>
# 						<a href="http://story.kakao.com/ch/seoul" class="ks" target="_blank" title="새창열림" onclick="se_click_logging('http://story.kakao.com/ch/seoul?tr_code=sns',location.href);">카카오스토리</a>
# 						<a href="http://www.youtube.com/seoullive" class="yt" target="_blank" title="새창열림" onclick="se_click_logging('http://www.youtube.com/seoullive?tr_code=sns',location.href);">유튜브</a>
# 						<a href="http://blog.seoul.go.kr" class="bl" target="_blank" title="새창열림" onclick="se_click_logging('http://blog.seoul.go.kr?tr_code=sns',location.href);">블로그</a>
# 					</div> -->
# <div class="seoul_banner">
# <div class="mobile_banner">
# <!-- Dighty : [우리동네키움포털] 모바일(신규) (664*140) 태그 -->
# <script type="text/javascript"><!--//<![CDATA[
#    var m3_b = '';
#    var m3_u = (location.protocol=='https:'?'https://delivery.dighty.com/www/delivery/ajs.php':'http://delivery.dighty.com/www/delivery/ajs.php');
#    var m3_r = Math.floor(Math.random()*99999999999);
#    if(document.cookie.indexOf('ACEUACS=')>-1){
#    var m3_b = document.cookie.substr(document.cookie.indexOf('ACEUACS=')+8,19);}
#    if (!document.MAX_used) document.MAX_used = ',';
#    document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#    document.write ("?zoneid=1010");
#    document.write ('&amp;cb=' + m3_r);
#    if (m3_b!='')document.write('&amp;bd=' + m3_b);
#    if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#    document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#    document.write ("&amp;loc=" + escape(window.location));
#    if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#    if (document.context) document.write ("&context=" + escape(document.context));
#    if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#    document.write ("'><\/scr"+"ipt>");
# //]]>--></script>
# <noscript>
# <a href="https://delivery.dighty.com/www/delivery/ck.php?n=1e48c442&amp;cb=INSERT_RANDOM_NUMBER_HERE" rel="noopener noreferrer" target="_blank">
# <img alt="" src="https://delivery.dighty.com/www/delivery/avw.php?zoneid=1010&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=1e48c442"/></a>
# </noscript>
# </div>
# <div class="pc_banner">
# <!-- NHN ACE : [우리동네키움포털] 메인하단 (1200*70) 태그 -->
# <script type="text/javascript">
# //<![CDATA[
#    var m3_b = '';
#    var m3_u = (location.protocol=='https:'?'https://delivery.dighty.com/www/delivery/ajs.php':'http://delivery.dighty.com/www/delivery/ajs.php');
#    var m3_r = Math.floor(Math.random()*99999999999);
#    if(document.cookie.indexOf('ACEUACS=')>-1){
#    var m3_b = document.cookie.substr(document.cookie.indexOf('ACEUACS=')+8,19);}
#    if (!document.MAX_used) document.MAX_used = ',';
#    document.write ("<scr"+"ipt type='text/javascript' src='"+m3_u);
#    document.write ("?zoneid=807");
#    document.write ('&amp;cb=' + m3_r);
#    if (m3_b!='')document.write('&amp;bd=' + m3_b);
#    if (document.MAX_used != ',') document.write ("&amp;exclude=" + document.MAX_used);
#    document.write (document.charset ? '&amp;charset='+document.charset : (document.characterSet ? '&amp;charset='+document.characterSet : ''));
#    document.write ("&amp;loc=" + escape(window.location));
#    if (document.referrer) document.write ("&amp;referer=" + escape(document.referrer));
#    if (document.context) document.write ("&context=" + escape(document.context));
#    if (document.mmm_fo) document.write ("&amp;mmm_fo=1");
#    document.write ("'><\/scr"+"ipt>");
# //]]>
# </script>
# <noscript>
# <a href="https://delivery.dighty.com/www/delivery/ck.php?n=6e7b33fd&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank" title="새창열림">
# <img alt="" src="https://delivery.dighty.com/www/delivery/avw.php?zoneid=807&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=6e7b33fd"/></a>
# </noscript>
# </div>
# </div>
# </div>
# </div>
# </div><!--footer_wrap END-->
# <div class="footer_wrap02">
# <div class="row">
# <div class="inner">
# <div class="seoul_logo"> <!-- 211130 seoul_logo class 추가 -->
# <a href="http://www.seoul.go.kr" rel="noopener" target="_blank" title="새창으로 열림">
# <img alt="I SEOUL U 로고" src="/icare/resources/idolbom/img/footer/img_brand1.png" title="I SEOUL U 로고">
# </img></a>
# </div>
# <div class="footer_info">
# <ul class="footer_link02"> <!-- 211130 mobile_none02 삭제 -->
# <li class="policy"><a href="/icare/privacyAgree.jsp">개인정보처리방침</a></li>
# <li class="policy"><a href="/icare/termsAgree.jsp">이용약관</a></li>
# <li class="policy"><a href="/icare/siteMap.jsp">누리집지도</a></li>
# <li class="policy"><a href="/icare/user/bbs/BD_selectBbsList.do?q_bbsCode=1012">오류신고</a></li>
# </ul>
# <div class="address">
# <p class="city">서울특별시청 04524 서울특별시 중구 세종대로 110 <span class="tel">대표전화 : 02-120</span>
# <p class="">Seoul Metropolitan Government all rights reserved</p>
# </p></div>
# </div>
# <span class="foo-logo inquiry"><em class="blind">문의 전화번호 120, 정보를 못찾으셨나요? 120 다산콜센터로 물어보세요!</em></span>
# <div class="mark">
# <ul>
# <li>
# <a href="#none">
# <img alt="엄마 아빠 행복프로젝트" src="/icare/resources/idolbom/img/footer/happiness_banner.png"/>
# </a>
# </li>
# <li>
# <a href="http://www.webwatch.or.kr/Situation/WA_Situation.html?MenuCD=110" rel="noopener" target="_blank" title="새창으로 열림">
# <img alt="과학기술정보통신부 WA(WEB접근성) 품질인증 마크, 웹와치(WebWatch) 2022.03.10 ~ 2023.03.09" src="/icare/resources/idolbom/img/footer/wa.png">
# </img></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div><!--footer_wrap02 END-->
# </footer>
# <!-- /.Footer -->
# <script src="//weblog.eseoul.go.kr/wlo/js/install.js" type="text/javascript"></script>
# </body>
# </html>

# %%
for item in 코드값목록:
    if item['key'] in ['q_svcClCode','q_clturEvent', 'q_tabVal']:
        print(item)
# Out:
# {'key': 'q_svcClCode', 'value': '1001', 'label': '우리동네 키움센터'}
# {'key': 'q_svcClCode', 'value': '1003', 'label': '지역 아동센터'}
# {'key': 'q_svcClCode', 'value': '1005', 'label': '초등 돌봄교실'}
# {'key': 'q_svcClCode', 'value': '1002', 'label': '공동육아방'}
# {'key': 'q_svcClCode', 'value': '1004', 'label': '공동육아 나눔터'}
# {'key': 'q_svcClCode', 'value': '1010', 'label': '청소년방과후아카데미'}
# {'key': 'q_svcClCode', 'value': '1006', 'label': '영·유아 보육시설'}
# {'key': 'q_clturEvent', 'value': '2002', 'label': '초등생 교육 프로그램'}
# {'key': 'q_clturEvent', 'value': '2003', 'label': '영·유아 교육 프로그램'}
# {'key': 'q_tabVal', 'value': '', 'label': '전체'}
# {'key': 'q_tabVal', 'value': '1001', 'label': '우리동네 키움센터'}
# {'key': 'q_tabVal', 'value': '1003', 'label': '지역 아동센터'}
# {'key': 'q_tabVal', 'value': '1005', 'label': '초등돌봄교실'}
# {'key': 'q_tabVal', 'value': '1002', 'label': '공동육아방'}
# {'key': 'q_tabVal', 'value': '1004', 'label': '공동육아 나눔터'}
# {'key': 'q_tabVal', 'value': '1010', 'label': '방과후 아카데미'}
# {'key': 'q_tabVal', 'value': '1006', 'label': '영.유아 보육시설'}
# {'key': 'q_tabVal', 'value': '1008', 'label': '교육'}
# {'key': 'q_tabVal', 'value': '1007', 'label': '지역보육정보'}

# %%
## 페이지당 카운트는 15개로 고정되어 있음
## 서비스별로 루프를 돌아서 처리해야함..
body.extend([('q_moreSvc', '1001'), ('q_tabVal', '1001'),
             ('q_rowPerPage', '50'),('q_currPage','1')])

# %%
response = web_request('POST', 'https://icare.seoul.go.kr/icare/user/fcltyInfoManage/BD_selectFcltyInfoManageList.do', body)

# %%
res_html = bs(response['text'], "html.parser")

# %%
total_cnt = res_html.select_one('p.board_info').text
total_cnt = total_cnt[total_cnt.index('전체'):total_cnt.index('건')]
total_cnt = re.sub(r'[^0-9]', '', total_cnt)
total_pages = math.ceil(int(total_cnt)/15)

# %%
# Out:
# fnView("1001","SP220901","송파18호점 우리동네키움센터(위례동2호점 송파키움센터)","");
# 송파18호점 우리동네키움센터(위례동2호점 송파키움센터)
# 주소서울특별시 송파구 위례북로4길 12
# 연락처:02-:431-:5515
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP220601","송파17호점 우리동네키움센터(거여2동 송파키움센터)","");
# 송파17호점 우리동네키움센터(거여2동 송파키움센터)
# 주소서울특별시 송파구 오금로 551
# 연락처:070-:7700-:9666
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP211001","송파16호점 우리동네키움센터(문정1동 송파키움센터)","");
# 송파16호점 우리동네키움센터(문정1동 송파키움센터)
# 주소서울특별시 송파구 송이로 198-1
# 연락처:02-:400-:1832
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1009","SP210101","송파15호점(융합형) 우리동네키움센터(잠실본동2호점 송파키움센터)","");
# 송파15호점(융합형) 우리동네키움센터(잠실본동2호점 송파키움센터)
# 주소서울특별시 송파구 백제고분로 139
# 연락처:02-:3432-:9576
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:송파구:초등학생
# fnView("1001","SP201203","송파10호점 우리동네키움센터(가락2동 송파키움센터)","");
# 송파10호점 우리동네키움센터(가락2동 송파키움센터)
# 주소서울특별시 송파구 중대로20길 14
# 연락처:02-:443-:2021
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP201206","송파13호점 우리동네키움센터(송파2동 송파키움센터)","");
# 송파13호점 우리동네키움센터(송파2동 송파키움센터)
# 주소서울특별시 송파구 송이로10길 12
# 연락처:02-:421-:2021
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1009","SP201204","송파11호점(융합형) 우리동네키움센터(오금동 송파키움센터)","");
# 송파11호점(융합형) 우리동네키움센터(오금동 송파키움센터)
# 주소서울특별시 송파구 동남로28길 40
# 연락처:02-:430-:1388
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 융합형키움센터:송파구:초등학생
# fnView("1001","SP201207","송파14호점 우리동네키움센터(장지동 송파키움센터)","");
# 송파14호점 우리동네키움센터(장지동 송파키움센터)
# 주소서울특별시 송파구 새말로8길 9
# 연락처:02-:402-:9395
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP201205","송파12호점 우리동네키움센터(방이1동 송파키움센터)","");
# 송파12호점 우리동네키움센터(방이1동 송파키움센터)
# 주소서울특별시 송파구 가락로 270
# 연락처:02-:421-:5874
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP201201","송파8호점 우리동네키움센터(석촌동 송파키움센터)","");
# 송파8호점 우리동네키움센터(석촌동 송파키움센터)
# 주소서울특별시 송파구 백제고분로37길 4
# 연락처:02-:6930-:5535
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP201202","송파9호점 우리동네키움센터(삼전동 2호점 송파키움센터)","");
# 송파9호점 우리동네키움센터(삼전동 2호점 송파키움센터)
# 주소서울특별시 송파구 석촌호수로 158
# 연락처:02-:417-:3233
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP201001","송파7호점 우리동네키움센터(위례동 송파키움센터)","");
# 송파7호점 우리동네키움센터(위례동 송파키움센터)
# 주소서울특별시 송파구 위례순환로 477
# 연락처:02-:6949-:3671
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP200501","송파5호점 우리동네키움센터(가락본동 송파키움센터)","");
# 송파5호점 우리동네키움센터(가락본동 송파키움센터)
# 주소서울특별시 송파구 오금로36길 36
# 연락처:02-:6925-:0985
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP200502","송파6호점 우리동네키움센터(문정2동 송파키움센터)","");
# 송파6호점 우리동네키움센터(문정2동 송파키움센터)
# 주소서울특별시 송파구 중대로4길 4
# 연락처:02-:2147-:5361
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생
# fnView("1001","SP191103","송파2호점 우리동네키움센터(송파1동 송파키움센터)","");
# 송파2호점 우리동네키움센터(송파1동 송파키움센터)
# 주소서울특별시 송파구 백제고분로 42길 5
# 연락처:02-:3432-:3331
# 이용료::::월 / ::::50,000 원::::  ::일 / ::::2,500 원
# 우리동네키움센터:송파구:초등학생

# %%
body = []
body = [('q_hiddenVal', 1),
 ('q_fcltyId', 'KC230101'),
 ('q_fclty', '1001')]

# %%
response = web_request('POST', '', body)

# %%
res_html = bs(response['text'], "html.parser")

# %%
res_html
table_ty01 m_table_ty01 mt_20 bb_b 현황정보
center_i_btn 예약현황 버튼

# %%
for item in res_html.select('table tr th,td'):
    print(item.text.strip().replace('\t',''))
# Out:
# 운영일
# 2023-01-01
# 전용면적
# 40 평방 미터
# 종사자 수
# 2 명
# 운영방식
# 사회적협동조합
# 시설형태
#
# 건물유형
# 공동주택
# 학기 중
# 월요일 – 금요일 (10:00 –
# 19:00)
# 방학 중
# 월요일 – 금요일 (09:00 –
# 18:00)
# 재량휴교일
# 09:00 –
# 18:00
# 토요일
# 미운영
# 정기돌봄
# 20명
# 일시돌봄
# 4명
# 월 이용료
# 50,000 원
# 일 이용료
# 2,500 원
# 이용료 안내
# 정기돌봄은 월
#
#
#
# 50,000 원
#
#
#
#
#
#
#
# ,일시(긴급)돌봄은 일2,500 원
#
#
#
# 으로 이용 가능하며, 이용료는 프로그램 활동비 등 관련 제반비용으로 구성됩니다.
# 추후 등록 예정
# 추후 등록 예정

# %%
# 예약 현황 # 예약신청
for item in res_html.select('div.center_i_btn a'):
    print(item.text, item['onclick'])
# Out:
# 예약현황 resvePopup('KC230101', 'N', '금천구 4호점 우리동네키움센터(시흥1동)','Y', '', '2022');
# 예약 신청 resveDev('Y','KC230101', '');

# %%
axis_info = res_html.select_one('div.center_infoBox a.center_info_btn02')['onclick']
axis_info = axis_info[axis_info.index('(')+1:axis_info.rindex(')')-1].translate(str.maketrans({"'":None}))
axis_info.split(',')[:2]
# Out:
# ['37.44889', '126.90323']

# %%
for item in res_html.select('div.gray_box a'):
    print(item.text, item['onclick'])
# 1001 종일 1002 시간제 1003 일시
# Out:
# 종일 돌봄 예약 신청 resveReq('1001','KC230101','Y','');
# 시간제 돌봄 예약 신청 resveReq('1002','KC230101','Y','');
# 일시 돌봄 예약 신청 resveReq('1003','KC230101','Y','');

# %%
var fnView = function(svcClCode, fcltyId, fcltyNm, siteUrl) {
    if (svcClCode == "1005" || svcClCode == "2003") {
        window.open(siteUrl, "_blank");
    } else if (svcClCode == "1007" || svcClCode == "2003") {
        $("#q_fclty").val(svcClCode);
        $("#q_clturEventEtcSn").val(fcltyId);
        $("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
        $("#searchForm").submit();
    } else if (svcClCode == "2001") {
        $("#q_fclty").val(svcClCode);
        $("#q_clturEventEtcSn").val(fcltyId);
        $("#q_gubun").val("1001");
        $("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
        $("#searchForm").submit();
    } else if (svcClCode == "2002") {
        $("#q_fclty").val(svcClCode);
        $("#q_clturEventEtcSn").val(fcltyId);
        $("#q_gubun").val("1002");
        $("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
        $("#searchForm").submit();
    } else if (svcClCode == "1006") {
        if (fcltyNm.indexOf("휴일보육") > 0) {
            window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
        } else if (fcltyNm.indexOf("시간보육") > 0) {
            window.open("https://iseoul.seoul.go.kr/portal/reservation/night_info.do", "_blank");
        } else if (fcltyNm.indexOf("365열린어린이집") > 0) {
            window.open("https://iseoul.seoul.go.kr/portal/reservation/holi_info.do", "_blank");
        } else if (fcltyNm.indexOf("거점형시간연장보육") > 0) {
            window.open("https://iseoul.seoul.go.kr/portal/reservation/dailyOpenPreschoolMiddle.do", "_blank");
        } else {
            window.open("https://iseoul.seoul.go.kr/portal/info/preSchoolList.do", "_blank");
        }
    } else if (svcClCode == "1008") {
        location.href = siteUrl;
    } else {
        $("#q_fclty").val(svcClCode);
        $("#q_fcltyId").val(fcltyId);
        $("#searchForm").attr("action", "BD_selectFcltyInfoManage.do");
        $("#searchForm").submit();
    }
}

# %%
var fnTabMove = function(tabVal) {
			var checked = "";
			if (tabVal == '1008') {        // 교육
				$("input:checkbox[id^=fac_2]:checked").each(function(i) {
					if (i != 0) {
						checked += ',';
					}
					checked += $(this).val();
				});
				$("#q_moreSvc").val(checked);
			} else if (tabVal == '1007') { // 지역보육정보
				$("input:checkbox[id^=fac_1]:checked").each(function(i) {
					if ($(this).val() != '2001') {
						checked = tabVal;
					} else {
						if (i != 0) {
							checked += ',';
						}
						checked += $(this).val();
					}
				});
				$("#q_moreSvc").val(checked);
			} else {
				$("#q_moreSvc").val(tabVal);
			}
			$("#q_tabVal").val(tabVal);

			$("#q_currPage").val(1);
			$("#q_searchAt").val("Y");
			$("#searchForm").submit();
		}
