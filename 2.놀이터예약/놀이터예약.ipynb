# %%
import requests

# %%
https://passport.livere.com/v1/auth/naver?redirectUrl=https://www.gangnam.go.kr/loginLivere.do
# returnUrl=%2Fmain.do
# 이녀석이 로그인후에 강남홈페이지로 가는 통로
#https://nid.naver.com/oauth2.0/authorize?auth_type=&response_type=code&redirect_uri=https%3A%2F%2Fpassport.livere.com%2Fv1%2Fauth%2Fnaver%2Fcallback&client_id=56vMBuwZrZtIb6B4KQ0W


https://www.gangnam.go.kr/resv/apply/segok_indoor_playground/list.do?mid=ID04_04070903

<a class="btn btn-xs btn-blue" href="/resv/reqst/segok_indoor_playground/1493/add.do?mid=ID04_04070903">

# %%
## 네이버를 로그인하고 세션을 유지하자
## 로그인 세션을 유지한 상태에서
## 해당페이지로 이동해서 날짜별로 예약가능한 목록을 출력한다
## 목록출력후 값을 선택해서 reqest 날려서 예약

# %%
## 세곡실내어린이 놀이터 예약
https://www.gangnam.go.kr/resv/apply/segok_indoor_playground/list.do?mid=ID04_04070903
## 일원실내어린이 놀이터 예약
https://www.gangnam.go.kr/resv/apply/irwon_playground/list.do?mid=ID04_04074703

## 예약 reqeust
## 1493이 해당 예약시간대이다
https://www.gangnam.go.kr/resv/reqst/segok_indoor_playground/1493/insert.do

##
calendar_tbl_wrap

# %%
r = requests.get('https://www.gangnam.go.kr/resv/apply/segok_indoor_playground/list.do?mid=ID04_04070903', data={})

# %%
payload={
    'id':'urloverme',
    'pw':'Tjtjdwls2!',
    'redirectUrl':'https://www.gangnam.go.kr/loginLivere.do'
}
r = requests.get('https://passport.livere.com/v1/auth/naver', data=payload)

# %%
with reqeusts.session() as s:
    # login page
    #s.get() blablak

# %%
r.text
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n<html lang="ko">\r\n<!-- start: HEAD -->\r\n<head>\r\n\t\r\n\t\r\n\t\t\r\n\t\r\n\t\r\n\t\r\n\t<meta http-equiv=\'X-UA-Compatible\' content="IE=edge" />\r\n\r\n\t<!-- start: META -->\r\n\t<meta charset="utf-8" />\r\n\t\r\n\t\r\n\t\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0, maximum-scale=1.0">\r\n\t<meta name="format-detection" content="telephone=no, address=no, email=no">\r\n\t<meta name="naver" content="nosublinks" />\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\t\r\n\r\n\r\n\t\r\n\t\r\n\t\t\t\r\n\t\t\r\n\r\n\r\n\t\r\n\t\r\n\r\n\r\n\t\r\n\r\n\r\n\r\n\r\n\r\n\r\n\t\r\n\t\r\n\r\n\r\n\t\r\n\t\r\n\r\n\r\n\t\r\n\r\n\r\n\t\t<title>강남구청 > 소통·참여 > 신청 > 세곡어린이실내놀이터 > 개인 예약</title>\r\n\t\t<link rel="image_src" href="https://www.gangnam.go.kr/assets/images/
# ...
